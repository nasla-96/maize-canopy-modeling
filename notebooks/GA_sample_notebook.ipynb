# %%
import os
import subprocess
import time
import random
import pygad
import configparser
from geomdl import exchange, multi, BSpline, operations, utilities
from geomdl.operations import rotate
from geomdl.visualization import VisMPL as vis
import numpy as np
import open3d as o3d
import copy
import pandas as pd
import time
import csv
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Function to calculate the length of the curve given control points (degree 3)
def calculate_curve_length(ctrlpts):
    curve = BSpline.Curve()
    curve.degree = 3
    curve.ctrlpts = ctrlpts
    curve.knotvector = utilities.generate_knot_vector(curve.degree, curve.ctrlpts_size)
    curve.delta = 0.01
    return operations.length_curve(curve)

# %%
# Function to calculate the width of the curve given control points (degree 2)
def calculate_curve_width(ctrlpts):
    curve = BSpline.Curve()
    curve.degree = 2
    curve.ctrlpts = ctrlpts
    curve.knotvector = utilities.generate_knot_vector(curve.degree, curve.ctrlpts_size)
    curve.delta = 0.01
    return operations.length_curve(curve)

# %%
def scale_length(points, multiplier, exclude_indices=[0,6,12], inplace=True):
    # Scale control points along the x-axis
    for idx, pt in enumerate(points):
        if idx not in exclude_indices:
            pt[0] *= multiplier
    return points

# %%
def scale_width(points, multiplier, exclude_indices=[1], inplace=True):
    # Scale control points along the y-axis
    for idx, pt in enumerate(points):
        if idx not in exclude_indices:
            pt[1] *= multiplier
    return points

# %%
def create_plant_obj(ga_instance, chromosome_idx, lengths, widths, theta, phi):
    # Load the surface data from a JSON file
    data = exchange.import_json("../3d_files/new_Mo17_manually_test_12leaves.json")
    surf_cont = multi.SurfaceContainer(data)

    for idx, surface_data in enumerate(surf_cont[1:]):
        # Step 1: calculate initial length and scaling factor
        initial_len = calculate_curve_length(surface_data.ctrlpts[6:12])
        scale_factor_len = lengths[idx] / initial_len

        # Step 2: Scale the control points for length
        scaled_len_ctrlpts = scale_length(surface_data.ctrlpts, scale_factor_len)

        # Step 3: Update the surface control points
        surface_data.ctrlpts = scaled_len_ctrlpts

        # Step 4: Extract control points sets in the v-direction after length scaling
        v_dir_sets = [surface_data.ctrlpts[i:i+6] for i in range(0, len(surface_data.ctrlpts), 6)]

        # Step 5: calculate initial width and scaling factor
        initial_width = calculate_curve_width([v_dir_set[2] for v_dir_set in v_dir_sets])
        width_factor = widths[idx] / initial_width

        # Step 6: Calculate and scale the widths
        for j in range(1, 5):
            curve_control_points = [v_dir_set[j] for v_dir_set in v_dir_sets]
            scaled_width_cntrlpts = scale_width(curve_control_points, width_factor)

            # Step 7: Update the v_dir_sets with the scaled width control points
            for k, v_dir_set in enumerate(v_dir_sets):
                v_dir_set[j] = scaled_width_cntrlpts[k]

        # Step 8: Rotate the surface
        z_angle = theta[idx]
        y_angle = phi[idx]
        rotate(surface_data, angle=y_angle, axis=1, inplace=True)
        rotate(surface_data, angle=z_angle, axis=2, inplace=True)

#     surf_cont.vis = vis.VisSurface(ctrlpts=False, trims=False)
#     surf_cont.render()
    # Export the updated surface to an OBJ file
    num_gen = ga_instance.generations_completed
    export_path = f"../GA_helios_cropped_120x24_12leaves/meshes/chromosome_{num_gen}_{chromosome_idx}.obj"
    exchange.export_obj(surf_cont, export_path)
    return export_path

# %%
import open3d as o3d
import numpy as np
import copy
import csv
import random

SEED = 42
np.random.seed(SEED)
random.seed(SEED)

def create_field(file_path, row_spacing, plant_spacing):
    mesh = o3d.io.read_triangle_mesh(file_path)
    
    # Scale the mesh to meters (assuming the current units are in centimeters)
    scale_factor = 0.01
    mesh.scale(scale_factor, center=mesh.get_center())
    
    # Translate the original mesh to the origin
    mesh.translate(-mesh.get_center())
    o3d.io.write_triangle_mesh(file_path, mesh)
    
    field = o3d.geometry.TriangleMesh()
    rotation_angles = []
    for i in range(-3, 3):  # Adjusted to -3 to 2 for a 6x6 field
        for j in range(-3, 3):  # Adjusted to -3 to 2 for a 6x6 field
            # Create a deep copy of the mesh and then translate it
            cloned_mesh = copy.deepcopy(mesh)
            
            # Apply a random rotation between -10 and 10 degrees around the Z-axis
            rotation_angle = random.uniform(-10, 10)
            rotation_radians = np.radians(rotation_angle)
            rotation_matrix = cloned_mesh.get_rotation_matrix_from_axis_angle([0, 0, rotation_radians])
            cloned_mesh.rotate(rotation_matrix, center=(0, 0, 0))

            translated_mesh = cloned_mesh.translate(np.array([i * plant_spacing, j * row_spacing, 0]), relative=True)
            field += translated_mesh
            
            rotation_angles.append(rotation_angle)

    # Translate the field by 0.5 * plant_spacing in the x direction and 0.5 * row_spacing in the y direction
    field.translate((-0.5 * plant_spacing, 0.5 * row_spacing, 0))

    # Crop a portion of the field
    cropped_field = field.crop(o3d.geometry.AxisAlignedBoundingBox(
        min_bound=(-2 * plant_spacing, -2 * row_spacing, -np.inf),
        max_bound=(2 * plant_spacing, 2 * row_spacing, np.inf)
    ))
    
    csv_file_path = "/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/rotation_info.csv"
    with open(csv_file_path, mode='a', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow([file_path] + rotation_angles)
        
    # Generate the output filepath by replacing ".obj" with "_field_cropped.obj"
    output_filepath = file_path.replace('.obj', '_field_cropped.obj')

    # Save the field mesh with the new name
    o3d.io.write_triangle_mesh(output_filepath, cropped_field)
    
#     # Print the center of the cropped field
#     center = cropped_field.get_center()
#     print(f"Center of the cropped field: {center}")

    return output_filepath

# Example usage
# file_path = "GA_rotate30/meshes/chromosome_97_64.obj"
# row_spacing = 0.00762
# plant_spacing = 0.001524
# output_filepath = create_field(file_path, row_spacing, plant_spacing)

# output_filepath

# %%
def update_config_file(config_file_path, field_path):
    config = configparser.ConfigParser()
    config.read(config_file_path)
    config.set('Paths', 'fieldfilepath', field_path)  # Update with field path
    with open(config_file_path, 'w') as configfile:
        config.write(configfile)

# %%
# Function to run the Helios simulation
def run_helios(config_file_path, device_id):
    try:
        os.environ["CUDA_VISIBLE_DEVICES"] = str(device_id)
#         process = subprocess.Popen(
#             ["./par_parallel", config_file_path], stdout=subprocess.PIPE, stderr=subprocess.DEVNULL, 
#             cwd="/work/mech-ai-scratch/nasla/helios_new/Helios/samples/par_parallel/build"
#         )
        process = subprocess.Popen(
            "module load mesa-glu && module load boost/1.86.0-gvbpdbb && ./par_parallel " + config_file_path,
            shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE,
            cwd="/work/mech-ai-scratch/nasla/helios_new/Helios/samples/par_parallel/build"
        )
        stdout, _ = process.communicate()

        if process.returncode == 0:
            return extract_PAR_from_output(stdout.decode())
        else:
            print("Helios execution failed with return code:", process.returncode)
            return None
    except Exception as e:
        print("An error occurred:", str(e))
        return None

# %%
def extract_PAR_from_output(output):
    for line in output.splitlines():
        if "PAR_VALUE:" in line:
            return float(line.split(":")[-1].strip())
    return None

# %%
def fitness_func(ga_instance, chromosome, chromosome_idx):
    try:
        # Reshape the chromosome to extract lengths, widths, theta, and phi
        chromosome_sets = np.reshape(chromosome, (4, 12))
        lengths = chromosome_sets[0]
        widths = chromosome_sets[1]
        theta = chromosome_sets[2]
        phi = chromosome_sets[3]

        # Create plant object and get the path
        plant_path = create_plant_obj(ga_instance, chromosome_idx, lengths, widths, theta, phi)

        # Set row and plant spacing in meters
        row_spacing = 0.762
        plant_spacing = 0.1524

        # Create the field and get the field path
        field_path = create_field(plant_path, row_spacing, plant_spacing)

        # Determine GPU ID and corresponding config file path
        gpu_id = (chromosome_idx % 8) // 2
        config_file_id = chromosome_idx % 8
        config_file_path = f"/work/mech-ai-scratch/nasla/helios_new/Helios/samples/par_parallel/configs/helios_config_gpu{config_file_id}.ini"

        # Update the configuration file with the new paths
        update_config_file(config_file_path, os.path.abspath(field_path))

        # Run the Helios simulation and get the PAR value
        PAR = run_helios(config_file_path, gpu_id)
        print(f"Chromosome Index: {chromosome_idx}, PAR Value: {PAR}, GPU: {gpu_id}")

        # Return the PAR value as the fitness score
        if PAR is not None:
            if np.isnan(PAR):
                print(f"PAR is NaN for chromosome index {chromosome_idx}, returning 0.0")
                return 0.0
            else:
                return PAR
        else:
            print(f"Chromosome Index: {chromosome_idx}, PAR is None, returning 0.0")
            return 0.0
    except Exception as e:
        print(f"Error in fitness function for chromosome index {chromosome_idx}: {str(e)}")
        return 0.0
# def fitness_func(ga_instance, chromosome, chromosome_idx):
#     try:
#         chromosome = np.asarray(chromosome, dtype=np.float32)

#         row_df = chromosome_to_surrogate_df(
#             chromosome=chromosome,
#             template_row=template_row,
#             checkpoint_n_leaves=meta["n_leaves"],
#         )

#         PAR = predict_surrogate_PAR_from_row(row_df)

#         print(f"Chromosome Index: {chromosome_idx}, Surrogate PAR Value: {PAR}")

#         if PAR is None:
#             print(f"Chromosome Index: {chromosome_idx}, PAR is None, returning 0.0")
#             return 0.0

#         if np.isnan(PAR):
#             print(f"Chromosome Index: {chromosome_idx}, PAR is NaN, returning 0.0")
#             return 0.0

#         return float(PAR)

#     except Exception as e:
#         print(f"Error in fitness function for chromosome index {chromosome_idx}: {str(e)}")
#         return 0.0

# %%
last_fitness = 0
def on_generation(ga_instance):
    global last_fitness
    print(f"Generation = {ga_instance.generations_completed}")

    # Ensure fitness array does not contain NaN values
    pop_fitness = np.nan_to_num(ga_instance.last_generation_fitness, nan=0.0)
    
    if pop_fitness.size > 0:
        best_solution, best_solution_fitness, best_match_idx = ga_instance.best_solution(pop_fitness=pop_fitness)
        print(f"Fitness    = {best_solution_fitness}")
        print(f"Change     = {best_solution_fitness - last_fitness}")
        last_fitness = best_solution_fitness
    else:
        print("Warning: Population fitness array is empty!")
        last_fitness = 0

# %%
gene_space = [
    {'low': 40, 'high': 110}, # For lengths
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 40, 'high': 110},
    {'low': 5, 'high': 14}, # For widths
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14},
    {'low': 5, 'high': 14}, 
    {'low': 0, 'high': 360}, # For theta
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': 0, 'high': 360},
    {'low': -45, 'high': 45}, # For phi
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45},
    {'low': -45, 'high': 45}
]

# %%
num_generations = 100

num_parents_mating = 50
# initial_pop = init_pop

sol_per_pop = 100
num_genes = 48
keep_elitism = 20

# init_range_low = 0.0
# init_range_high = 1.0

# parent_selection_type = "sss"
# keep_parents = 5

# crossover_type = "single_point"

mutation_type = "random"
mutation_percent_genes = 5

# %%
def main():
    try:
        
        ga_instance = pygad.GA(
        sol_per_pop=sol_per_pop,                  
        num_genes=num_genes,
        gene_type=float,
        num_generations=num_generations,
        num_parents_mating=num_parents_mating,

        fitness_func=fitness_func,
        parent_selection_type="tournament",
        K_tournament=3,
        keep_parents=0,
#         keep_elitism=3,

        crossover_type="uniform",

        mutation_type="random",
        mutation_percent_genes=mutation_percent_genes,
        mutation_by_replacement=True,

        gene_space=gene_space,
        on_generation=on_generation,

        save_best_solutions=True,
        save_solutions=True,
        parallel_processing=["process", 8],
        stop_criteria=["saturate_15"],

        random_seed=42     # <-- fixed seed for reproducibility
        )
        
        t1 = time.time()
        ga_instance.run()
        t2 = time.time()
        print("Time is", t2-t1)
        
        pd.DataFrame(ga_instance.best_solutions).to_csv('/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/best_solutions.csv')
        pd.DataFrame(ga_instance.solutions).to_csv('/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/solutions.csv')
        ga_instance.plot_fitness(save_dir='/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/fitness.png')
        ga_instance.plot_genes(graph_type="histogram")
        solution, solution_fitness, solution_idx = ga_instance.best_solution(ga_instance.last_generation_fitness)
        print("Best Solution:", solution)
        print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
        ga_instance.save(filename='/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/ga_instance')
        pd.DataFrame(ga_instance.best_solutions_fitness).to_csv('/work/mech-ai-scratch/nasla/PAR_model/GA_helios_cropped_120x24_12leaves/best_solutions_fitness.csv')
    except Exception as e:
        print(f"An error occurred in main: {str(e)}")

# %%
if __name__ == '__main__':
    main()
# Out:
# /work/mech-ai/nasla/anaconda/envs/nurbs/lib/python3.8/site-packages/pygad/pygad.py:1139: UserWarning: The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.
#   warnings.warn("The 'delay_after_gen' parameter is deprecated starting from PyGAD 3.3.0. To delay or pause the evolution after each generation, assign a callback function/method to the 'on_generation' parameter to adds some time delay.")
# /work/mech-ai/nasla/anaconda/envs/nurbs/lib/python3.8/site-packages/pygad/pygad.py:1153: UserWarning: Use the 'save_best_solutions' parameter with caution as it may cause memory overflow when either the number of generations or number of genes is large.
#   warnings.warn("Use the 'save_best_solutions' parameter with caution as it may cause memory overflow when either the number of generations or number of genes is large.")
# /work/mech-ai/nasla/anaconda/envs/nurbs/lib/python3.8/site-packages/pygad/pygad.py:1162: UserWarning: Use the 'save_solutions' parameter with caution as it may cause memory overflow when either the number of generations, number of genes, or number of solutions in population is large.
#   warnings.warn("Use the 'save_solutions' parameter with caution as it may cause memory overflow when either the number of generations, number of genes, or number of solutions in population is large.")
# Chromosome Index: 2, PAR Value: 16394.0, GPU: 1
# Chromosome Index: 3, PAR Value: 13628.2, GPU: 1
# Chromosome Index: 6, PAR Value: 14466.9, GPU: 3
# Chromosome Index: 7, PAR Value: 14822.2, GPU: 3
# Chromosome Index: 4, PAR Value: 15969.7, GPU: 2
# Chromosome Index: 5, PAR Value: 17656.3, GPU: 2
# Chromosome Index: 0, PAR Value: 14673.6, GPU: 0
# Chromosome Index: 1, PAR Value: 15101.1, GPU: 0
# Chromosome Index: 8, PAR Value: 16715.9, GPU: 0
# Chromosome Index: 9, PAR Value: 15122.7, GPU: 0
# Chromosome Index: 11, PAR Value: 16844.7, GPU: 1
# Chromosome Index: 10, PAR Value: 16731.3, GPU: 1
# Chromosome Index: 12, PAR Value: 14037.7, GPU: 2
# Chromosome Index: 14, PAR Value: 15197.1, GPU: 3
# Chromosome Index: 15, PAR Value: 17035.5, GPU: 3
# Chromosome Index: 13, PAR Value: 15621.6, GPU: 2
# Chromosome Index: 16, PAR Value: 15183.3, GPU: 0
# Chromosome Index: 17, PAR Value: 14536.6, GPU: 0
# Chromosome Index: 18, PAR Value: 16801.8, GPU: 1
# Chromosome Index: 19, PAR Value: 15719.7, GPU: 1
# Chromosome Index: 22, PAR Value: 14038.6, GPU: 3
# Chromosome Index: 21, PAR Value: 16914.9, GPU: 2
# Chromosome Index: 23, PAR Value: 14897.6, GPU: 3
# Chromosome Index: 20, PAR Value: 15038.5, GPU: 2
# Chromosome Index: 24, PAR Value: 17239.4, GPU: 0
# Chromosome Index: 26, PAR Value: 15515.2, GPU: 1
# Chromosome Index: 25, PAR Value: 14197.4, GPU: 0
# Chromosome Index: 27, PAR Value: 16617.5, GPU: 1
# Chromosome Index: 29, PAR Value: 15355.2, GPU: 2
# Chromosome Index: 31, PAR Value: 16118.1, GPU: 3
# Chromosome Index: 28, PAR Value: 17337.3, GPU: 2
# Chromosome Index: 30, PAR Value: 14973.9, GPU: 3
# Chromosome Index: 32, PAR Value: 17267.5, GPU: 0
# Chromosome Index: 33, PAR Value: 16452.7, GPU: 0
# Chromosome Index: 34, PAR Value: 16707.9, GPU: 1
# Chromosome Index: 35, PAR Value: 14699.3, GPU: 1
# Chromosome Index: 36, PAR Value: 14412.3, GPU: 2
# Chromosome Index: 38, PAR Value: 15674.0, GPU: 3
# Chromosome Index: 37, PAR Value: 16915.6, GPU: 2
# Chromosome Index: 39, PAR Value: 14960.5, GPU: 3
# Chromosome Index: 40, PAR Value: 15336.8, GPU: 0
# Chromosome Index: 41, PAR Value: 14659.1, GPU: 0
# Chromosome Index: 43, PAR Value: 15717.2, GPU: 1
# Chromosome Index: 42, PAR Value: 16472.7, GPU: 1
# Chromosome Index: 46, PAR Value: 15275.2, GPU: 3
# Chromosome Index: 44, PAR Value: 16967.8, GPU: 2
# Chromosome Index: 45, PAR Value: 15793.9, GPU: 2
# Chromosome Index: 47, PAR Value: 15808.6, GPU: 3
# Chromosome Index: 48, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 48, returning 0.0
# Chromosome Index: 49, PAR Value: 16705.4, GPU: 0
# Chromosome Index: 50, PAR Value: 14529.0, GPU: 1
# Chromosome Index: 51, PAR Value: 15567.4, GPU: 1
# Chromosome Index: 53, PAR Value: 15043.0, GPU: 2
# Chromosome Index: 52, PAR Value: 18184.0, GPU: 2
# Chromosome Index: 54, PAR Value: 15565.3, GPU: 3
# Chromosome Index: 55, PAR Value: 15619.8, GPU: 3
# Chromosome Index: 57, PAR Value: 15147.9, GPU: 0
# Chromosome Index: 56, PAR Value: 13466.7, GPU: 0
# Chromosome Index: 58, PAR Value: 17030.3, GPU: 1
# Chromosome Index: 59, PAR Value: 15342.9, GPU: 1
# Chromosome Index: 60, PAR Value: 14459.5, GPU: 2
# Chromosome Index: 61, PAR Value: 17537.8, GPU: 2
# Chromosome Index: 63, PAR Value: 14336.4, GPU: 3
# Chromosome Index: 62, PAR Value: 17120.1, GPU: 3
# Chromosome Index: 64, PAR Value: 14595.1, GPU: 0
# Chromosome Index: 65, PAR Value: 16108.0, GPU: 0
# Chromosome Index: 66, PAR Value: 14496.7, GPU: 1
# Chromosome Index: 67, PAR Value: 13507.2, GPU: 1
# Chromosome Index: 68, PAR Value: 15712.4, GPU: 2
# Chromosome Index: 70, PAR Value: 15259.8, GPU: 3
# Chromosome Index: 69, PAR Value: 16840.9, GPU: 2
# Chromosome Index: 71, PAR Value: 15157.9, GPU: 3
# Chromosome Index: 72, PAR Value: 16094.3, GPU: 0
# Chromosome Index: 73, PAR Value: 16000.0, GPU: 0
# Chromosome Index: 74, PAR Value: 16393.9, GPU: 1
# Chromosome Index: 75, PAR Value: 15679.3, GPU: 1
# Chromosome Index: 78, PAR Value: 15318.6, GPU: 3
# Chromosome Index: 77, PAR Value: 15868.8, GPU: 2
# Chromosome Index: 76, PAR Value: 14232.4, GPU: 2
# Chromosome Index: 79, PAR Value: 14935.9, GPU: 3
# Chromosome Index: 80, PAR Value: 17731.1, GPU: 0
# Chromosome Index: 82, PAR Value: 15011.7, GPU: 1
# Chromosome Index: 83, PAR Value: 15411.9, GPU: 1
# Chromosome Index: 81, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 81, returning 0.0
# Chromosome Index: 86, PAR Value: 14177.1, GPU: 3
# Chromosome Index: 85, PAR Value: 14671.1, GPU: 2
# Chromosome Index: 84, PAR Value: 15886.4, GPU: 2
# Chromosome Index: 87, PAR Value: 14103.6, GPU: 3
# Chromosome Index: 88, PAR Value: 16179.3, GPU: 0
# Chromosome Index: 89, PAR Value: 15546.4, GPU: 0
# Chromosome Index: 91, PAR Value: 14109.9, GPU: 1
# Chromosome Index: 90, PAR Value: 17843.7, GPU: 1
# Chromosome Index: 95, PAR Value: 16874.1, GPU: 3
# Chromosome Index: 94, PAR Value: 15820.3, GPU: 3
# Chromosome Index: 93, PAR Value: 16168.8, GPU: 2
# Chromosome Index: 92, PAR Value: 15745.6, GPU: 2
# Chromosome Index: 96, PAR Value: 16426.1, GPU: 0
# Chromosome Index: 97, PAR Value: 17681.0, GPU: 0
# Chromosome Index: 98, PAR Value: 16588.8, GPU: 1
# Chromosome Index: 99, PAR Value: 16762.9, GPU: 1
# Chromosome Index: 2, PAR Value: 17218.2, GPU: 1
# Chromosome Index: 3, PAR Value: 17458.7, GPU: 1
# Chromosome Index: 5, PAR Value: 17489.5, GPU: 2
# Chromosome Index: 6, PAR Value: 17013.1, GPU: 3
# Chromosome Index: 4, PAR Value: 18299.1, GPU: 2
# Chromosome Index: 7, PAR Value: 15358.5, GPU: 3
# Chromosome Index: 1, PAR Value: 17072.0, GPU: 0
# Chromosome Index: 8, PAR Value: 16013.3, GPU: 0
# Chromosome Index: 14, PAR Value: 15965.6, GPU: 3
# Chromosome Index: 10, PAR Value: 15376.5, GPU: 1
# Chromosome Index: 9, PAR Value: 16395.6, GPU: 0
# Chromosome Index: 15, PAR Value: 14827.9, GPU: 3
# Chromosome Index: 11, PAR Value: 15695.7, GPU: 1
# Chromosome Index: 12, PAR Value: 17593.1, GPU: 2
# Chromosome Index: 13, PAR Value: 16658.9, GPU: 2
# Chromosome Index: 16, PAR Value: 15634.8, GPU: 0
# Chromosome Index: 17, PAR Value: 18012.0, GPU: 0
# Chromosome Index: 19, PAR Value: 16010.9, GPU: 1
# Chromosome Index: 18, PAR Value: 17678.0, GPU: 1
# Chromosome Index: 20, PAR Value: 17672.8, GPU: 2
# Chromosome Index: 22, PAR Value: 15125.1, GPU: 3
# Chromosome Index: 23, PAR Value: 15494.1, GPU: 3
# Chromosome Index: 21, PAR Value: 16872.3, GPU: 2
# Chromosome Index: 24, PAR Value: 14632.4, GPU: 0
# Chromosome Index: 25, PAR Value: 14893.2, GPU: 0
# Chromosome Index: 27, PAR Value: 15167.9, GPU: 1
# Chromosome Index: 26, PAR Value: 16075.4, GPU: 1
# Chromosome Index: 28, PAR Value: 14668.5, GPU: 2
# Chromosome Index: 29, PAR Value: 16598.9, GPU: 2
# Chromosome Index: 31, PAR Value: 15174.5, GPU: 3
# Chromosome Index: 30, PAR Value: 17816.5, GPU: 3
# Chromosome Index: 32, PAR Value: 15738.7, GPU: 0
# Chromosome Index: 33, PAR Value: 18024.2, GPU: 0
# Chromosome Index: 35, PAR Value: 16465.4, GPU: 1
# Chromosome Index: 34, PAR Value: 14958.4, GPU: 1
# Chromosome Index: 36, PAR Value: 16919.6, GPU: 2
# Chromosome Index: 40, PAR Value: 16824.0, GPU: 0
# Chromosome Index: 37, PAR Value: 18079.2, GPU: 2
# Chromosome Index: 39, PAR Value: 19026.2, GPU: 3
# Chromosome Index: 38, PAR Value: 16963.5, GPU: 3
# Chromosome Index: 41, PAR Value: 17287.0, GPU: 0
# Chromosome Index: 42, PAR Value: 15844.0, GPU: 1
# Chromosome Index: 43, PAR Value: 16230.8, GPU: 1
# Chromosome Index: 44, PAR Value: 15172.1, GPU: 2
# Chromosome Index: 47, PAR Value: 15129.3, GPU: 3
# Chromosome Index: 48, PAR Value: 15393.5, GPU: 0
# Chromosome Index: 46, PAR Value: 18486.9, GPU: 3
# Chromosome Index: 45, PAR Value: 14781.8, GPU: 2
# Chromosome Index: 49, PAR Value: 14178.3, GPU: 0
# Chromosome Index: 50, PAR Value: 16192.7, GPU: 1
# Chromosome Index: 51, PAR Value: 17060.0, GPU: 1
# Chromosome Index: 53, PAR Value: 16568.4, GPU: 2
# Chromosome Index: 52, PAR Value: 17311.3, GPU: 2
# Chromosome Index: 54, PAR Value: 17689.0, GPU: 3
# Chromosome Index: 55, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 55, returning 0.0
# Chromosome Index: 56, PAR Value: 14922.7, GPU: 0
# Chromosome Index: 57, PAR Value: 14636.9, GPU: 0
# Chromosome Index: 58, PAR Value: 16422.8, GPU: 1
# Chromosome Index: 59, PAR Value: 15780.1, GPU: 1
# Chromosome Index: 60, PAR Value: 14962.4, GPU: 2
# Chromosome Index: 63, PAR Value: 15395.0, GPU: 3
# Chromosome Index: 61, PAR Value: 16557.2, GPU: 2
# Chromosome Index: 62, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 62, returning 0.0
# Chromosome Index: 64, PAR Value: 17031.4, GPU: 0
# Chromosome Index: 65, PAR Value: 16971.2, GPU: 0
# Chromosome Index: 66, PAR Value: 14842.8, GPU: 1
# Chromosome Index: 67, PAR Value: 18071.6, GPU: 1
# Chromosome Index: 68, PAR Value: 16306.2, GPU: 2
# Chromosome Index: 69, PAR Value: 16327.0, GPU: 2
# Chromosome Index: 70, PAR Value: 15815.5, GPU: 3
# Chromosome Index: 72, PAR Value: 15289.3, GPU: 0
# Chromosome Index: 71, PAR Value: 17118.5, GPU: 3
# Chromosome Index: 73, PAR Value: 16969.6, GPU: 0
# Chromosome Index: 74, PAR Value: 15447.7, GPU: 1
# Chromosome Index: 75, PAR Value: 14907.1, GPU: 1
# Chromosome Index: 76, PAR Value: 16212.9, GPU: 2
# Chromosome Index: 77, PAR Value: 14881.5, GPU: 2
# Chromosome Index: 80, PAR Value: 16654.6, GPU: 0
# Chromosome Index: 81, PAR Value: 15924.3, GPU: 0
# Chromosome Index: 78, PAR Value: 17954.8, GPU: 3
# Chromosome Index: 79, PAR Value: 16839.0, GPU: 3
# Chromosome Index: 82, PAR Value: 16450.1, GPU: 1
# Chromosome Index: 83, PAR Value: 16664.3, GPU: 1
# Chromosome Index: 85, PAR Value: 16529.6, GPU: 2
# Chromosome Index: 84, PAR Value: 16813.5, GPU: 2
# Chromosome Index: 87, PAR Value: 15798.8, GPU: 3
# Chromosome Index: 86, PAR Value: 15647.4, GPU: 3
# Chromosome Index: 88, PAR Value: 16772.3, GPU: 0
# Chromosome Index: 89, PAR Value: 17902.2, GPU: 0
# Chromosome Index: 90, PAR Value: 16527.2, GPU: 1
# Chromosome Index: 91, PAR Value: 16490.8, GPU: 1
# Chromosome Index: 93, PAR Value: 16730.1, GPU: 2
# Chromosome Index: 92, PAR Value: 17340.3, GPU: 2
# Chromosome Index: 94, PAR Value: 15406.2, GPU: 3
# Chromosome Index: 95, PAR Value: 17435.0, GPU: 3
# Chromosome Index: 96, PAR Value: 15369.5, GPU: 0
# Chromosome Index: 97, PAR Value: 17735.7, GPU: 0
# Chromosome Index: 98, PAR Value: 15544.4, GPU: 1
# Chromosome Index: 99, PAR Value: 15683.3, GPU: 1
# Generation = 1
# Fitness    = 19026.2
# Change     = 19026.2
# Chromosome Index: 2, PAR Value: 17135.7, GPU: 1
# Chromosome Index: 3, PAR Value: 18520.4, GPU: 1
# Chromosome Index: 4, PAR Value: 15871.7, GPU: 2
# Chromosome Index: 7, PAR Value: 15227.3, GPU: 3
# Chromosome Index: 5, PAR Value: 17414.4, GPU: 2
# Chromosome Index: 6, PAR Value: 17687.2, GPU: 3
# Chromosome Index: 8, PAR Value: 16166.7, GPU: 0
# Chromosome Index: 1, PAR Value: 15293.4, GPU: 0
# Chromosome Index: 10, PAR Value: 18264.7, GPU: 1
# Chromosome Index: 11, PAR Value: 16616.6, GPU: 1
# Chromosome Index: 9, PAR Value: 16810.5, GPU: 0
# Chromosome Index: 12, PAR Value: 16462.0, GPU: 2
# Chromosome Index: 13, PAR Value: 17772.0, GPU: 2
# Chromosome Index: 14, PAR Value: 16836.8, GPU: 3
# Chromosome Index: 15, PAR Value: 15862.5, GPU: 3
# Chromosome Index: 16, PAR Value: 16704.1, GPU: 0
# Chromosome Index: 18, PAR Value: 17615.7, GPU: 1
# Chromosome Index: 19, PAR Value: 17480.3, GPU: 1
# Chromosome Index: 17, PAR Value: 16731.2, GPU: 0
# Chromosome Index: 20, PAR Value: 16731.2, GPU: 2
# Chromosome Index: 22, PAR Value: 17191.8, GPU: 3
# Chromosome Index: 21, PAR Value: 15699.8, GPU: 2
# Chromosome Index: 23, PAR Value: 16698.2, GPU: 3
# Chromosome Index: 24, PAR Value: 16976.4, GPU: 0
# Chromosome Index: 26, PAR Value: 19227.8, GPU: 1
# Chromosome Index: 25, PAR Value: 18156.2, GPU: 0
# Chromosome Index: 27, PAR Value: 17935.3, GPU: 1
# Chromosome Index: 28, PAR Value: 17786.8, GPU: 2
# Chromosome Index: 30, PAR Value: 17124.0, GPU: 3
# Chromosome Index: 29, PAR Value: 18360.2, GPU: 2
# Chromosome Index: 31, PAR Value: 17122.2, GPU: 3
# Chromosome Index: 32, PAR Value: 17022.5, GPU: 0
# Chromosome Index: 33, PAR Value: 14539.3, GPU: 0
# Chromosome Index: 35, PAR Value: 16023.5, GPU: 1
# Chromosome Index: 34, PAR Value: 16219.2, GPU: 1
# Chromosome Index: 37, PAR Value: 17497.0, GPU: 2
# Chromosome Index: 36, PAR Value: 18345.1, GPU: 2
# Chromosome Index: 38, PAR Value: 17396.2, GPU: 3
# Chromosome Index: 39, PAR Value: 16735.3, GPU: 3
# Chromosome Index: 40, PAR Value: 16926.9, GPU: 0
# Chromosome Index: 41, PAR Value: 16637.7, GPU: 0
# Chromosome Index: 42, PAR Value: 15323.3, GPU: 1
# Chromosome Index: 43, PAR Value: 17230.5, GPU: 1
# Chromosome Index: 44, PAR Value: 17954.8, GPU: 2
# Chromosome Index: 45, PAR Value: 17294.2, GPU: 2
# Chromosome Index: 47, PAR Value: 16677.8, GPU: 3
# Chromosome Index: 46, PAR Value: 18135.6, GPU: 3
# Chromosome Index: 48, PAR Value: 14838.8, GPU: 0
# Chromosome Index: 49, PAR Value: 15970.7, GPU: 0
# Chromosome Index: 50, PAR Value: 16838.4, GPU: 1
# Chromosome Index: 51, PAR Value: 16052.7, GPU: 1
# Chromosome Index: 52, PAR Value: 16351.9, GPU: 2
# Chromosome Index: 53, PAR Value: 18919.9, GPU: 2
# Chromosome Index: 54, PAR Value: 15960.9, GPU: 3
# Chromosome Index: 55, PAR Value: 16631.5, GPU: 3
# Chromosome Index: 56, PAR Value: 17723.4, GPU: 0
# Chromosome Index: 58, PAR Value: 15194.0, GPU: 1
# Chromosome Index: 59, PAR Value: 16629.9, GPU: 1
# Chromosome Index: 57, PAR Value: 16575.1, GPU: 0
# Chromosome Index: 60, PAR Value: 16682.3, GPU: 2
# Chromosome Index: 62, PAR Value: 18570.5, GPU: 3
# Chromosome Index: 61, PAR Value: 17503.8, GPU: 2
# Chromosome Index: 63, PAR Value: 19437.7, GPU: 3
# Chromosome Index: 66, PAR Value: 16047.7, GPU: 1
# Chromosome Index: 64, PAR Value: 18234.4, GPU: 0
# Chromosome Index: 67, PAR Value: 16981.3, GPU: 1
# Chromosome Index: 65, PAR Value: 14556.3, GPU: 0
# Chromosome Index: 68, PAR Value: 17149.3, GPU: 2
# Chromosome Index: 69, PAR Value: 16914.0, GPU: 2
# Chromosome Index: 70, PAR Value: 17546.1, GPU: 3
# Chromosome Index: 71, PAR Value: 15473.7, GPU: 3
# Chromosome Index: 74, PAR Value: 18081.8, GPU: 1
# Chromosome Index: 75, PAR Value: 17133.3, GPU: 1
# Chromosome Index: 72, PAR Value: 18783.4, GPU: 0
# Chromosome Index: 73, PAR Value: 16012.5, GPU: 0
# Chromosome Index: 76, PAR Value: 17954.9, GPU: 2
# Chromosome Index: 77, PAR Value: 18212.7, GPU: 2
# Chromosome Index: 79, PAR Value: 17804.1, GPU: 3
# Chromosome Index: 78, PAR Value: 16409.0, GPU: 3
# Chromosome Index: 82, PAR Value: 17419.6, GPU: 1
# Chromosome Index: 80, PAR Value: 16724.6, GPU: 0
# Chromosome Index: 81, PAR Value: 15619.0, GPU: 0
# Chromosome Index: 83, PAR Value: 18541.7, GPU: 1
# Chromosome Index: 84, PAR Value: 17907.6, GPU: 2
# Chromosome Index: 87, PAR Value: 17033.5, GPU: 3
# Chromosome Index: 86, PAR Value: 17920.1, GPU: 3
# Chromosome Index: 85, PAR Value: 17229.9, GPU: 2
# Chromosome Index: 88, PAR Value: 15711.2, GPU: 0
# Chromosome Index: 89, PAR Value: 17230.5, GPU: 0
# Chromosome Index: 90, PAR Value: 18234.6, GPU: 1
# Chromosome Index: 91, PAR Value: 17022.2, GPU: 1
# Chromosome Index: 92, PAR Value: 16439.3, GPU: 2
# Chromosome Index: 93, PAR Value: 17085.3, GPU: 2
# Chromosome Index: 96, PAR Value: 15922.1, GPU: 0
# Chromosome Index: 95, PAR Value: 16930.4, GPU: 3
# Chromosome Index: 97, PAR Value: 17884.8, GPU: 0
# Chromosome Index: 94, PAR Value: 16393.5, GPU: 3
# Chromosome Index: 98, PAR Value: 15955.9, GPU: 1
# Chromosome Index: 99, PAR Value: 15658.3, GPU: 1
# Generation = 2
# Fitness    = 19437.7
# Change     = 411.5
# Chromosome Index: 3, PAR Value: 18224.8, GPU: 1
# Chromosome Index: 2, PAR Value: 18775.7, GPU: 1
# Chromosome Index: 6, PAR Value: 18014.5, GPU: 3
# Chromosome Index: 7, PAR Value: 18433.1, GPU: 3
# Chromosome Index: 5, PAR Value: 16841.4, GPU: 2
# Chromosome Index: 1, PAR Value: 19465.0, GPU: 0
# Chromosome Index: 4, PAR Value: 18803.1, GPU: 2
# Chromosome Index: 8, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 8, returning 0.0
# Chromosome Index: 9, PAR Value: 17894.4, GPU: 0
# Chromosome Index: 10, PAR Value: 17479.0, GPU: 1
# Chromosome Index: 14, PAR Value: 18175.5, GPU: 3
# Chromosome Index: 15, PAR Value: 17558.3, GPU: 3
# Chromosome Index: 16, PAR Value: 18423.1, GPU: 0
# Chromosome Index: 11, PAR Value: 18373.7, GPU: 1
# Chromosome Index: 12, PAR Value: 17956.7, GPU: 2
# Chromosome Index: 13, PAR Value: 16065.3, GPU: 2
# Chromosome Index: 17, PAR Value: 17028.8, GPU: 0
# Chromosome Index: 20, PAR Value: 16615.3, GPU: 2
# Chromosome Index: 19, PAR Value: 17653.2, GPU: 1
# Chromosome Index: 18, PAR Value: 16909.3, GPU: 1
# Chromosome Index: 24, PAR Value: 15014.6, GPU: 0
# Chromosome Index: 21, PAR Value: 17307.9, GPU: 2
# Chromosome Index: 22, PAR Value: 14849.4, GPU: 3
# Chromosome Index: 23, PAR Value: 18781.3, GPU: 3
# Chromosome Index: 25, PAR Value: 16949.5, GPU: 0
# Chromosome Index: 27, PAR Value: 18688.2, GPU: 1
# Chromosome Index: 26, PAR Value: 17692.9, GPU: 1
# Chromosome Index: 31, PAR Value: 18008.5, GPU: 3
# Chromosome Index: 28, PAR Value: 18480.8, GPU: 2
# Chromosome Index: 32, PAR Value: 16886.0, GPU: 0
# Chromosome Index: 30, PAR Value: 16956.1, GPU: 3
# Chromosome Index: 29, PAR Value: 16769.6, GPU: 2
# Chromosome Index: 33, PAR Value: 18016.4, GPU: 0
# Chromosome Index: 35, PAR Value: 17943.1, GPU: 1
# Chromosome Index: 40, PAR Value: 16050.2, GPU: 0
# Chromosome Index: 34, PAR Value: 16956.3, GPU: 1
# Chromosome Index: 36, PAR Value: 16487.8, GPU: 2
# Chromosome Index: 38, PAR Value: 16519.9, GPU: 3
# Chromosome Index: 39, PAR Value: 18112.2, GPU: 3
# Chromosome Index: 41, PAR Value: 16507.4, GPU: 0
# Chromosome Index: 37, PAR Value: 17307.0, GPU: 2
# Chromosome Index: 42, PAR Value: 18316.5, GPU: 1
# Chromosome Index: 43, PAR Value: 17228.5, GPU: 1
# Chromosome Index: 44, PAR Value: 17163.8, GPU: 2
# Chromosome Index: 49, PAR Value: 16507.0, GPU: 0
# Chromosome Index: 47, PAR Value: 17552.2, GPU: 3
# Chromosome Index: 48, PAR Value: 18955.0, GPU: 0
# Chromosome Index: 45, PAR Value: 17967.8, GPU: 2
# Chromosome Index: 46, PAR Value: 17689.7, GPU: 3
# Chromosome Index: 51, PAR Value: 19325.5, GPU: 1
# Chromosome Index: 50, PAR Value: 18873.2, GPU: 1
# Chromosome Index: 56, PAR Value: 18203.1, GPU: 0
# Chromosome Index: 57, PAR Value: 18494.0, GPU: 0
# Chromosome Index: 52, PAR Value: 16722.1, GPU: 2
# Chromosome Index: 54, PAR Value: 18508.4, GPU: 3
# Chromosome Index: 53, PAR Value: 17204.9, GPU: 2
# Chromosome Index: 55, PAR Value: 15870.7, GPU: 3
# Chromosome Index: 58, PAR Value: 17856.8, GPU: 1
# Chromosome Index: 59, PAR Value: 17138.3, GPU: 1
# Chromosome Index: 60, PAR Value: 16760.4, GPU: 2
# Chromosome Index: 61, PAR Value: 18885.5, GPU: 2
# Chromosome Index: 65, PAR Value: 17390.9, GPU: 0
# Chromosome Index: 62, PAR Value: 18439.2, GPU: 3
# Chromosome Index: 64, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 64, returning 0.0
# Chromosome Index: 63, PAR Value: 18369.2, GPU: 3
# Chromosome Index: 67, PAR Value: 15847.0, GPU: 1
# Chromosome Index: 66, PAR Value: 17643.2, GPU: 1
# Chromosome Index: 72, PAR Value: 16327.5, GPU: 0
# Chromosome Index: 68, PAR Value: 16648.4, GPU: 2
# Chromosome Index: 73, PAR Value: 18373.7, GPU: 0
# Chromosome Index: 70, PAR Value: 16593.7, GPU: 3
# Chromosome Index: 71, PAR Value: 16255.7, GPU: 3
# Chromosome Index: 69, PAR Value: 18735.4, GPU: 2
# Chromosome Index: 74, PAR Value: 16591.7, GPU: 1
# Chromosome Index: 75, PAR Value: 18011.6, GPU: 1
# Chromosome Index: 76, PAR Value: 17343.2, GPU: 2
# Chromosome Index: 77, PAR Value: 18041.7, GPU: 2
# Chromosome Index: 78, PAR Value: 16870.8, GPU: 3
# Chromosome Index: 79, PAR Value: 17975.4, GPU: 3
# Chromosome Index: 80, PAR Value: 17085.5, GPU: 0
# Chromosome Index: 81, PAR Value: 17910.7, GPU: 0
# Chromosome Index: 82, PAR Value: 16616.0, GPU: 1
# Chromosome Index: 83, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 83, returning 0.0
# Chromosome Index: 84, PAR Value: 16791.9, GPU: 2
# Chromosome Index: 85, PAR Value: 18589.6, GPU: 2
# Chromosome Index: 88, PAR Value: 17395.7, GPU: 0
# Chromosome Index: 89, PAR Value: 17559.7, GPU: 0
# Chromosome Index: 87, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 87, returning 0.0
# Chromosome Index: 86, PAR Value: 17800.8, GPU: 3
# Chromosome Index: 90, PAR Value: 15602.8, GPU: 1
# Chromosome Index: 91, PAR Value: 18761.6, GPU: 1
# Chromosome Index: 92, PAR Value: 18360.8, GPU: 2
# Chromosome Index: 93, PAR Value: 16893.4, GPU: 2
# Chromosome Index: 94, PAR Value: 17159.7, GPU: 3
# Chromosome Index: 95, PAR Value: 18949.7, GPU: 3
# Chromosome Index: 96, PAR Value: 18301.3, GPU: 0
# Chromosome Index: 97, PAR Value: 18267.4, GPU: 0
# Chromosome Index: 98, PAR Value: 19169.1, GPU: 1
# Chromosome Index: 99, PAR Value: 17374.7, GPU: 1
# Generation = 3
# Fitness    = 19465.0
# Change     = 27.299999999999272
# Chromosome Index: 3, PAR Value: 17196.4, GPU: 1
# Chromosome Index: 2, PAR Value: 19189.8, GPU: 1
# Chromosome Index: 6, PAR Value: 17660.8, GPU: 3
# Chromosome Index: 7, PAR Value: 15590.8, GPU: 3
# Chromosome Index: 1, PAR Value: 17003.8, GPU: 0
# Chromosome Index: 8, PAR Value: 17527.1, GPU: 0
# Chromosome Index: 5, PAR Value: 16976.5, GPU: 2
# Chromosome Index: 4, PAR Value: 17171.4, GPU: 2
# Chromosome Index: 9, PAR Value: 17939.7, GPU: 0
# Chromosome Index: 14, PAR Value: 18927.5, GPU: 3
# Chromosome Index: 15, PAR Value: 19032.1, GPU: 3
# Chromosome Index: 12, PAR Value: 16836.2, GPU: 2
# Chromosome Index: 13, PAR Value: 17147.6, GPU: 2
# Chromosome Index: 10, PAR Value: 17574.9, GPU: 1
# Chromosome Index: 11, PAR Value: 18007.3, GPU: 1
# Chromosome Index: 16, PAR Value: 17850.9, GPU: 0
# Chromosome Index: 17, PAR Value: 19093.6, GPU: 0
# Chromosome Index: 18, PAR Value: 20417.0, GPU: 1
# Chromosome Index: 19, PAR Value: 18958.0, GPU: 1
# Chromosome Index: 22, PAR Value: 18022.5, GPU: 3
# Chromosome Index: 23, PAR Value: 19818.9, GPU: 3
# Chromosome Index: 20, PAR Value: 18852.3, GPU: 2
# Chromosome Index: 21, PAR Value: 20125.3, GPU: 2
# Chromosome Index: 24, PAR Value: 18357.0, GPU: 0
# Chromosome Index: 25, PAR Value: 19239.3, GPU: 0
# Chromosome Index: 26, PAR Value: 18884.2, GPU: 1
# Chromosome Index: 27, PAR Value: 18266.5, GPU: 1
# Chromosome Index: 30, PAR Value: 17446.1, GPU: 3
# Chromosome Index: 31, PAR Value: 17518.3, GPU: 3
# Chromosome Index: 29, PAR Value: 17479.8, GPU: 2
# Chromosome Index: 32, PAR Value: 17232.1, GPU: 0
# Chromosome Index: 28, PAR Value: 16537.4, GPU: 2
# Chromosome Index: 33, PAR Value: 17350.9, GPU: 0
# Chromosome Index: 34, PAR Value: 17775.1, GPU: 1
# Chromosome Index: 35, PAR Value: 17672.8, GPU: 1
# Chromosome Index: 38, PAR Value: 18310.8, GPU: 3
# Chromosome Index: 39, PAR Value: 17288.2, GPU: 3
# Chromosome Index: 40, PAR Value: 15500.9, GPU: 0
# Chromosome Index: 41, PAR Value: 18393.8, GPU: 0
# Chromosome Index: 36, PAR Value: 16568.5, GPU: 2
# Chromosome Index: 37, PAR Value: 17984.5, GPU: 2
# Chromosome Index: 42, PAR Value: 16011.9, GPU: 1
# Chromosome Index: 43, PAR Value: 19141.0, GPU: 1
# Chromosome Index: 46, PAR Value: 18801.1, GPU: 3
# Chromosome Index: 47, PAR Value: 17436.2, GPU: 3
# Chromosome Index: 44, PAR Value: 18249.0, GPU: 2
# Chromosome Index: 45, PAR Value: 17261.8, GPU: 2
# Chromosome Index: 48, PAR Value: 17580.2, GPU: 0
# Chromosome Index: 49, PAR Value: 18257.3, GPU: 0
# Chromosome Index: 50, PAR Value: 17627.6, GPU: 1
# Chromosome Index: 51, PAR Value: 17447.2, GPU: 1
# Chromosome Index: 54, PAR Value: 18289.3, GPU: 3
# Chromosome Index: 52, PAR Value: 18116.8, GPU: 2
# Chromosome Index: 55, PAR Value: 17736.8, GPU: 3
# Chromosome Index: 53, PAR Value: 19187.5, GPU: 2
# Chromosome Index: 57, PAR Value: 15854.3, GPU: 0
# Chromosome Index: 56, PAR Value: 18142.2, GPU: 0
# Chromosome Index: 58, PAR Value: 17564.0, GPU: 1
# Chromosome Index: 59, PAR Value: 18651.7, GPU: 1
# Chromosome Index: 62, PAR Value: 17678.3, GPU: 3
# Chromosome Index: 63, PAR Value: 16165.3, GPU: 3
# Chromosome Index: 61, PAR Value: 18242.7, GPU: 2
# Chromosome Index: 60, PAR Value: 19157.8, GPU: 2
# Chromosome Index: 64, PAR Value: 18002.2, GPU: 0
# Chromosome Index: 65, PAR Value: 18244.9, GPU: 0
# Chromosome Index: 66, PAR Value: 18330.6, GPU: 1
# Chromosome Index: 67, PAR Value: 17322.8, GPU: 1
# Chromosome Index: 68, PAR Value: 18436.2, GPU: 2
# Chromosome Index: 70, PAR Value: 18866.1, GPU: 3
# Chromosome Index: 69, PAR Value: 19108.5, GPU: 2
# Chromosome Index: 72, PAR Value: 19129.5, GPU: 0
# Chromosome Index: 73, PAR Value: 18711.6, GPU: 0
# Chromosome Index: 71, PAR Value: 17981.3, GPU: 3
# Chromosome Index: 74, PAR Value: 18361.1, GPU: 1
# Chromosome Index: 75, PAR Value: 18065.4, GPU: 1
# Chromosome Index: 80, PAR Value: 17313.9, GPU: 0
# Chromosome Index: 79, PAR Value: 17297.9, GPU: 3
# Chromosome Index: 81, PAR Value: 16955.8, GPU: 0
# Chromosome Index: 78, PAR Value: 15342.8, GPU: 3
# Chromosome Index: 77, PAR Value: 19687.3, GPU: 2
# Chromosome Index: 76, PAR Value: 18196.3, GPU: 2
# Chromosome Index: 82, PAR Value: 17776.8, GPU: 1
# Chromosome Index: 83, PAR Value: 16906.8, GPU: 1
# Chromosome Index: 84, PAR Value: 17114.5, GPU: 2
# Chromosome Index: 86, PAR Value: 18681.2, GPU: 3
# Chromosome Index: 88, PAR Value: 19213.0, GPU: 0
# Chromosome Index: 85, PAR Value: 18453.7, GPU: 2
# Chromosome Index: 89, PAR Value: 18756.0, GPU: 0
# Chromosome Index: 90, PAR Value: 18754.6, GPU: 1
# Chromosome Index: 87, PAR Value: 17349.6, GPU: 3
# Chromosome Index: 91, PAR Value: 17789.8, GPU: 1
# Chromosome Index: 96, PAR Value: 18224.6, GPU: 0
# Chromosome Index: 92, PAR Value: 19182.6, GPU: 2
# Chromosome Index: 93, PAR Value: 18289.4, GPU: 2
# Chromosome Index: 98, PAR Value: 16931.6, GPU: 1
# Chromosome Index: 97, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 97, returning 0.0
# Chromosome Index: 94, PAR Value: 18616.6, GPU: 3
# Chromosome Index: 95, PAR Value: 18053.1, GPU: 3
# Chromosome Index: 99, PAR Value: 16378.5, GPU: 1
# Generation = 4
# Fitness    = 20417.0
# Change     = 952.0
# Chromosome Index: 2, PAR Value: 16793.3, GPU: 1
# Chromosome Index: 3, PAR Value: 17668.6, GPU: 1
# Chromosome Index: 4, PAR Value: 16993.3, GPU: 2
# Chromosome Index: 7, PAR Value: 18327.9, GPU: 3
# Chromosome Index: 1, PAR Value: 19145.1, GPU: 0
# Chromosome Index: 5, PAR Value: 17031.2, GPU: 2
# Chromosome Index: 6, PAR Value: 16847.3, GPU: 3
# Chromosome Index: 8, PAR Value: 19058.5, GPU: 0
# Chromosome Index: 9, PAR Value: 18643.8, GPU: 0
# Chromosome Index: 11, PAR Value: 19842.3, GPU: 1
# Chromosome Index: 10, PAR Value: 17491.7, GPU: 1
# Chromosome Index: 12, PAR Value: 19425.6, GPU: 2
# Chromosome Index: 15, PAR Value: 19935.5, GPU: 3
# Chromosome Index: 14, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 14, returning 0.0
# Chromosome Index: 16, PAR Value: 20367.4, GPU: 0
# Chromosome Index: 13, PAR Value: 18188.4, GPU: 2
# Chromosome Index: 18, PAR Value: 17732.8, GPU: 1
# Chromosome Index: 17, PAR Value: 17920.6, GPU: 0
# Chromosome Index: 19, PAR Value: 17955.2, GPU: 1
# Chromosome Index: 20, PAR Value: 16704.4, GPU: 2
# Chromosome Index: 24, PAR Value: 18629.0, GPU: 0
# Chromosome Index: 22, PAR Value: 18311.0, GPU: 3
# Chromosome Index: 21, PAR Value: 18328.2, GPU: 2
# Chromosome Index: 23, PAR Value: 19958.6, GPU: 3
# Chromosome Index: 25, PAR Value: 19886.7, GPU: 0
# Chromosome Index: 26, PAR Value: 18971.8, GPU: 1
# Chromosome Index: 27, PAR Value: 17963.6, GPU: 1
# Chromosome Index: 29, PAR Value: 18853.2, GPU: 2
# Chromosome Index: 28, PAR Value: 20007.2, GPU: 2
# Chromosome Index: 30, PAR Value: 20415.5, GPU: 3
# Chromosome Index: 31, PAR Value: 18325.5, GPU: 3
# Chromosome Index: 32, PAR Value: 17914.1, GPU: 0
# Chromosome Index: 33, PAR Value: 17180.7, GPU: 0
# Chromosome Index: 34, PAR Value: 18278.6, GPU: 1
# Chromosome Index: 35, PAR Value: 18369.2, GPU: 1
# Chromosome Index: 38, PAR Value: 18397.3, GPU: 3
# Chromosome Index: 37, PAR Value: 19662.1, GPU: 2
# Chromosome Index: 40, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 40, returning 0.0
# Chromosome Index: 39, PAR Value: 19595.0, GPU: 3
# Chromosome Index: 36, PAR Value: 17818.6, GPU: 2
# Chromosome Index: 41, PAR Value: 20131.0, GPU: 0
# Chromosome Index: 42, PAR Value: 19465.4, GPU: 1
# Chromosome Index: 43, PAR Value: 20545.6, GPU: 1
# Chromosome Index: 47, PAR Value: 18053.2, GPU: 3
# Chromosome Index: 46, PAR Value: 18247.3, GPU: 3
# Chromosome Index: 44, PAR Value: 20058.4, GPU: 2
# Chromosome Index: 45, PAR Value: 19822.0, GPU: 2
# Chromosome Index: 48, PAR Value: 18450.2, GPU: 0
# Chromosome Index: 49, PAR Value: 17722.0, GPU: 0
# Chromosome Index: 50, PAR Value: 17317.4, GPU: 1
# Chromosome Index: 51, PAR Value: 19308.8, GPU: 1
# Chromosome Index: 53, PAR Value: 18385.6, GPU: 2
# Chromosome Index: 52, PAR Value: 18737.1, GPU: 2
# Chromosome Index: 54, PAR Value: 16458.5, GPU: 3
# Chromosome Index: 55, PAR Value: 18573.6, GPU: 3
# Chromosome Index: 56, PAR Value: 17475.8, GPU: 0
# Chromosome Index: 57, PAR Value: 18362.1, GPU: 0
# Chromosome Index: 58, PAR Value: 18072.5, GPU: 1
# Chromosome Index: 59, PAR Value: 19050.5, GPU: 1
# Chromosome Index: 61, PAR Value: 17038.8, GPU: 2
# Chromosome Index: 60, PAR Value: 19103.0, GPU: 2
# Chromosome Index: 62, PAR Value: 17589.3, GPU: 3
# Chromosome Index: 63, PAR Value: 18443.0, GPU: 3
# Chromosome Index: 64, PAR Value: 17883.4, GPU: 0
# Chromosome Index: 65, PAR Value: 19427.9, GPU: 0
# Chromosome Index: 66, PAR Value: 18808.7, GPU: 1
# Chromosome Index: 67, PAR Value: 17838.8, GPU: 1
# Chromosome Index: 68, PAR Value: 17329.9, GPU: 2
# Chromosome Index: 70, PAR Value: 15942.0, GPU: 3
# Chromosome Index: 71, PAR Value: 19325.1, GPU: 3
# Chromosome Index: 69, PAR Value: 18306.3, GPU: 2
# Chromosome Index: 72, PAR Value: 18630.1, GPU: 0
# Chromosome Index: 73, PAR Value: 16912.7, GPU: 0
# Chromosome Index: 74, PAR Value: 18592.1, GPU: 1
# Chromosome Index: 75, PAR Value: 20243.1, GPU: 1
# Chromosome Index: 76, PAR Value: 16615.5, GPU: 2
# Chromosome Index: 77, PAR Value: 18120.3, GPU: 2
# Chromosome Index: 78, PAR Value: 17183.1, GPU: 3
# Chromosome Index: 79, PAR Value: 18164.0, GPU: 3
# Chromosome Index: 80, PAR Value: 17906.4, GPU: 0
# Chromosome Index: 81, PAR Value: 19551.7, GPU: 0
# Chromosome Index: 82, PAR Value: 20252.1, GPU: 1
# Chromosome Index: 83, PAR Value: 17890.1, GPU: 1
# Chromosome Index: 84, PAR Value: 18310.9, GPU: 2
# Chromosome Index: 85, PAR Value: 18574.0, GPU: 2
# Chromosome Index: 87, PAR Value: 19049.2, GPU: 3
# Chromosome Index: 88, PAR Value: 17914.0, GPU: 0
# Chromosome Index: 86, PAR Value: 19096.3, GPU: 3
# Chromosome Index: 89, PAR Value: 20814.7, GPU: 0
# Chromosome Index: 90, PAR Value: 20035.2, GPU: 1
# Chromosome Index: 91, PAR Value: 18481.7, GPU: 1
# Chromosome Index: 93, PAR Value: 20241.6, GPU: 2
# Chromosome Index: 92, PAR Value: 19468.4, GPU: 2
# Chromosome Index: 96, PAR Value: 16949.7, GPU: 0
# Chromosome Index: 94, PAR Value: 18476.0, GPU: 3
# Chromosome Index: 95, PAR Value: 19019.1, GPU: 3
# Chromosome Index: 97, PAR Value: 18452.0, GPU: 0
# Chromosome Index: 98, PAR Value: 18097.9, GPU: 1
# Chromosome Index: 99, PAR Value: 18282.9, GPU: 1
# Generation = 5
# Fitness    = 20814.7
# Change     = 397.7000000000007
# Chromosome Index: 8, PAR Value: 19492.0, GPU: 0
# Chromosome Index: 7, PAR Value: 20725.3, GPU: 3
# Chromosome Index: 1, PAR Value: 19404.9, GPU: 0
# Chromosome Index: 6, PAR Value: 19287.3, GPU: 3
# Chromosome Index: 2, PAR Value: 19111.8, GPU: 1
# Chromosome Index: 5, PAR Value: 19723.9, GPU: 2
# Chromosome Index: 3, PAR Value: 20203.3, GPU: 1
# Chromosome Index: 4, PAR Value: 19816.0, GPU: 2
# Chromosome Index: 9, PAR Value: 19414.7, GPU: 0
# Chromosome Index: 10, PAR Value: 19914.8, GPU: 1
# Chromosome Index: 14, PAR Value: 17771.9, GPU: 3
# Chromosome Index: 15, PAR Value: 17493.5, GPU: 3
# Chromosome Index: 11, PAR Value: 19546.3, GPU: 1
# Chromosome Index: 12, PAR Value: 20072.8, GPU: 2
# Chromosome Index: 13, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 13, returning 0.0
# Chromosome Index: 16, PAR Value: 19810.0, GPU: 0
# Chromosome Index: 17, PAR Value: 17520.3, GPU: 0
# Chromosome Index: 22, PAR Value: 18914.5, GPU: 3
# Chromosome Index: 18, PAR Value: 18312.5, GPU: 1
# Chromosome Index: 23, PAR Value: 20453.3, GPU: 3
# Chromosome Index: 24, PAR Value: 19717.4, GPU: 0
# Chromosome Index: 21, PAR Value: 19163.0, GPU: 2
# Chromosome Index: 20, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 20, returning 0.0
# Chromosome Index: 19, PAR Value: 19398.8, GPU: 1
# Chromosome Index: 25, PAR Value: 20904.3, GPU: 0
# Chromosome Index: 30, PAR Value: 20500.4, GPU: 3
# Chromosome Index: 26, PAR Value: 20094.7, GPU: 1
# Chromosome Index: 31, PAR Value: 19339.3, GPU: 3
# Chromosome Index: 32, PAR Value: 18954.4, GPU: 0
# Chromosome Index: 29, PAR Value: 18973.3, GPU: 2
# Chromosome Index: 27, PAR Value: 20570.5, GPU: 1
# Chromosome Index: 28, PAR Value: 18217.3, GPU: 2
# Chromosome Index: 33, PAR Value: 16475.9, GPU: 0
# Chromosome Index: 34, PAR Value: 17967.4, GPU: 1
# Chromosome Index: 35, PAR Value: 19010.0, GPU: 1
# Chromosome Index: 39, PAR Value: 17909.2, GPU: 3
# Chromosome Index: 38, PAR Value: 19374.3, GPU: 3
# Chromosome Index: 40, PAR Value: 17511.1, GPU: 0
# Chromosome Index: 41, PAR Value: 17371.4, GPU: 0
# Chromosome Index: 37, PAR Value: 20292.4, GPU: 2
# Chromosome Index: 36, PAR Value: 19583.6, GPU: 2
# Chromosome Index: 42, PAR Value: 17314.7, GPU: 1
# Chromosome Index: 43, PAR Value: 18067.7, GPU: 1
# Chromosome Index: 46, PAR Value: 18891.3, GPU: 3
# Chromosome Index: 44, PAR Value: 18959.4, GPU: 2
# Chromosome Index: 45, PAR Value: 20471.3, GPU: 2
# Chromosome Index: 47, PAR Value: 18841.3, GPU: 3
# Chromosome Index: 48, PAR Value: 18434.9, GPU: 0
# Chromosome Index: 49, PAR Value: 19197.2, GPU: 0
# Chromosome Index: 50, PAR Value: 17855.2, GPU: 1
# Chromosome Index: 51, PAR Value: 18938.0, GPU: 1
# Chromosome Index: 56, PAR Value: 20369.6, GPU: 0
# Chromosome Index: 52, PAR Value: 19371.9, GPU: 2
# Chromosome Index: 53, PAR Value: 19147.6, GPU: 2
# Chromosome Index: 55, PAR Value: 18534.6, GPU: 3
# Chromosome Index: 57, PAR Value: 19845.0, GPU: 0
# Chromosome Index: 54, PAR Value: 19472.3, GPU: 3
# Chromosome Index: 58, PAR Value: 19357.5, GPU: 1
# Chromosome Index: 59, PAR Value: 19279.3, GPU: 1
# Chromosome Index: 60, PAR Value: 20641.6, GPU: 2
# Chromosome Index: 63, PAR Value: 19212.7, GPU: 3
# Chromosome Index: 64, PAR Value: 19771.1, GPU: 0
# Chromosome Index: 61, PAR Value: 19333.2, GPU: 2
# Chromosome Index: 62, PAR Value: 18709.3, GPU: 3
# Chromosome Index: 65, PAR Value: 19320.3, GPU: 0
# Chromosome Index: 66, PAR Value: 19111.7, GPU: 1
# Chromosome Index: 67, PAR Value: 18318.5, GPU: 1
# Chromosome Index: 72, PAR Value: 19247.0, GPU: 0
# Chromosome Index: 71, PAR Value: 19014.9, GPU: 3
# Chromosome Index: 68, PAR Value: 19789.4, GPU: 2
# Chromosome Index: 73, PAR Value: 18974.8, GPU: 0
# Chromosome Index: 70, PAR Value: 18613.6, GPU: 3
# Chromosome Index: 69, PAR Value: 17446.7, GPU: 2
# Chromosome Index: 74, PAR Value: 18853.6, GPU: 1
# Chromosome Index: 75, PAR Value: 20516.2, GPU: 1
# Chromosome Index: 80, PAR Value: 19616.2, GPU: 0
# Chromosome Index: 77, PAR Value: 18996.0, GPU: 2
# Chromosome Index: 76, PAR Value: 19989.8, GPU: 2
# Chromosome Index: 81, PAR Value: 20793.7, GPU: 0
# Chromosome Index: 78, PAR Value: 19644.3, GPU: 3
# Chromosome Index: 79, PAR Value: 19666.0, GPU: 3
# Chromosome Index: 82, PAR Value: 18745.2, GPU: 1
# Chromosome Index: 83, PAR Value: 17244.2, GPU: 1
# Chromosome Index: 84, PAR Value: 18337.4, GPU: 2
# Chromosome Index: 85, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 85, returning 0.0
# Chromosome Index: 89, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 89, returning 0.0
# Chromosome Index: 88, PAR Value: 19582.1, GPU: 0
# Chromosome Index: 86, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 86, returning 0.0
# Chromosome Index: 87, PAR Value: 20238.8, GPU: 3
# Chromosome Index: 90, PAR Value: 17958.9, GPU: 1
# Chromosome Index: 91, PAR Value: 18511.6, GPU: 1
# Chromosome Index: 92, PAR Value: 18277.6, GPU: 2
# Chromosome Index: 93, PAR Value: 18830.2, GPU: 2
# Chromosome Index: 96, PAR Value: 20592.3, GPU: 0
# Chromosome Index: 97, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 97, returning 0.0
# Chromosome Index: 94, PAR Value: 19200.6, GPU: 3
# Chromosome Index: 95, PAR Value: 19282.1, GPU: 3
# Chromosome Index: 98, PAR Value: 18492.8, GPU: 1
# Chromosome Index: 99, PAR Value: 16877.5, GPU: 1
# Generation = 6
# Fitness    = 20904.3
# Change     = 89.59999999999854
# Chromosome Index: 2, PAR Value: 20902.2, GPU: 1
# Chromosome Index: 5, PAR Value: 20325.0, GPU: 2
# Chromosome Index: 3, PAR Value: 19559.2, GPU: 1
# Chromosome Index: 4, PAR Value: 19436.7, GPU: 2
# Chromosome Index: 6, PAR Value: 19578.0, GPU: 3
# Chromosome Index: 8, PAR Value: 20240.1, GPU: 0
# Chromosome Index: 1, PAR Value: 20377.9, GPU: 0
# Chromosome Index: 7, PAR Value: 18398.6, GPU: 3
# Chromosome Index: 10, PAR Value: 19249.9, GPU: 1
# Chromosome Index: 12, PAR Value: 18282.5, GPU: 2
# Chromosome Index: 9, PAR Value: 19913.6, GPU: 0
# Chromosome Index: 14, PAR Value: 18895.4, GPU: 3
# Chromosome Index: 11, PAR Value: 19725.1, GPU: 1
# Chromosome Index: 15, PAR Value: 20811.2, GPU: 3
# Chromosome Index: 13, PAR Value: 18421.0, GPU: 2
# Chromosome Index: 16, PAR Value: 19749.0, GPU: 0
# Chromosome Index: 17, PAR Value: 19854.6, GPU: 0
# Chromosome Index: 18, PAR Value: 19389.4, GPU: 1
# Chromosome Index: 19, PAR Value: 19091.0, GPU: 1
# Chromosome Index: 21, PAR Value: 20477.6, GPU: 2
# Chromosome Index: 20, PAR Value: 18792.8, GPU: 2
# Chromosome Index: 24, PAR Value: 20249.4, GPU: 0
# Chromosome Index: 22, PAR Value: 20154.2, GPU: 3
# Chromosome Index: 23, PAR Value: 19902.5, GPU: 3
# Chromosome Index: 25, PAR Value: 19074.5, GPU: 0
# Chromosome Index: 27, PAR Value: 18823.2, GPU: 1
# Chromosome Index: 26, PAR Value: 19064.7, GPU: 1
# Chromosome Index: 28, PAR Value: 18079.3, GPU: 2
# Chromosome Index: 32, PAR Value: 19192.5, GPU: 0
# Chromosome Index: 31, PAR Value: 18446.1, GPU: 3
# Chromosome Index: 29, PAR Value: 17395.8, GPU: 2
# Chromosome Index: 30, PAR Value: 19141.3, GPU: 3
# Chromosome Index: 33, PAR Value: 21222.9, GPU: 0
# Chromosome Index: 36, PAR Value: 20243.4, GPU: 2
# Chromosome Index: 34, PAR Value: 19683.7, GPU: 1
# Chromosome Index: 40, PAR Value: 19968.9, GPU: 0
# Chromosome Index: 35, PAR Value: 20229.4, GPU: 1
# Chromosome Index: 39, PAR Value: 20218.9, GPU: 3
# Chromosome Index: 38, PAR Value: 20404.8, GPU: 3
# Chromosome Index: 37, PAR Value: 18884.6, GPU: 2
# Chromosome Index: 41, PAR Value: 18581.0, GPU: 0
# Chromosome Index: 44, PAR Value: 19247.0, GPU: 2
# Chromosome Index: 42, PAR Value: 18665.9, GPU: 1
# Chromosome Index: 45, PAR Value: 19506.3, GPU: 2
# Chromosome Index: 47, PAR Value: 19848.4, GPU: 3
# Chromosome Index: 43, PAR Value: 19648.4, GPU: 1
# Chromosome Index: 46, PAR Value: 20871.1, GPU: 3
# Chromosome Index: 48, PAR Value: 19967.4, GPU: 0
# Chromosome Index: 49, PAR Value: 19912.8, GPU: 0
# Chromosome Index: 52, PAR Value: 19573.9, GPU: 2
# Chromosome Index: 53, PAR Value: 19903.0, GPU: 2
# Chromosome Index: 51, PAR Value: 20043.3, GPU: 1
# Chromosome Index: 50, PAR Value: 19404.1, GPU: 1
# Chromosome Index: 55, PAR Value: 19168.4, GPU: 3
# Chromosome Index: 56, PAR Value: 19240.6, GPU: 0
# Chromosome Index: 54, PAR Value: 20395.7, GPU: 3
# Chromosome Index: 57, PAR Value: 18279.4, GPU: 0
# Chromosome Index: 58, PAR Value: 20026.1, GPU: 1
# Chromosome Index: 61, PAR Value: 20155.4, GPU: 2
# Chromosome Index: 60, PAR Value: 19634.0, GPU: 2
# Chromosome Index: 59, PAR Value: 20596.1, GPU: 1
# Chromosome Index: 64, PAR Value: 19583.9, GPU: 0
# Chromosome Index: 62, PAR Value: 19818.0, GPU: 3
# Chromosome Index: 65, PAR Value: 19006.2, GPU: 0
# Chromosome Index: 63, PAR Value: 18331.5, GPU: 3
# Chromosome Index: 72, PAR Value: 20193.7, GPU: 0
# Chromosome Index: 66, PAR Value: 20803.8, GPU: 1
# Chromosome Index: 68, PAR Value: 19929.9, GPU: 2
# Chromosome Index: 69, PAR Value: 19284.5, GPU: 2
# Chromosome Index: 73, PAR Value: 19455.7, GPU: 0
# Chromosome Index: 67, PAR Value: 19855.4, GPU: 1
# Chromosome Index: 70, PAR Value: 20397.6, GPU: 3
# Chromosome Index: 71, PAR Value: 20853.6, GPU: 3
# Chromosome Index: 74, PAR Value: 21049.1, GPU: 1
# Chromosome Index: 75, PAR Value: 19619.0, GPU: 1
# Chromosome Index: 77, PAR Value: 19881.4, GPU: 2
# Chromosome Index: 76, PAR Value: 19681.0, GPU: 2
# Chromosome Index: 78, PAR Value: 17936.3, GPU: 3
# Chromosome Index: 81, PAR Value: 18754.4, GPU: 0
# Chromosome Index: 79, PAR Value: 19264.2, GPU: 3
# Chromosome Index: 80, PAR Value: 17981.6, GPU: 0
# Chromosome Index: 82, PAR Value: 20006.1, GPU: 1
# Chromosome Index: 83, PAR Value: 20821.9, GPU: 1
# Chromosome Index: 85, PAR Value: 20233.1, GPU: 2
# Chromosome Index: 84, PAR Value: 19605.2, GPU: 2
# Chromosome Index: 89, PAR Value: 18407.2, GPU: 0
# Chromosome Index: 88, PAR Value: 20502.4, GPU: 0
# Chromosome Index: 86, PAR Value: 19922.0, GPU: 3
# Chromosome Index: 87, PAR Value: 19982.4, GPU: 3
# Chromosome Index: 90, PAR Value: 18043.5, GPU: 1
# Chromosome Index: 91, PAR Value: 19435.0, GPU: 1
# Chromosome Index: 92, PAR Value: 20953.3, GPU: 2
# Chromosome Index: 94, PAR Value: 19259.7, GPU: 3
# Chromosome Index: 93, PAR Value: 19157.8, GPU: 2
# Chromosome Index: 95, PAR Value: 20942.1, GPU: 3
# Chromosome Index: 96, PAR Value: 20114.2, GPU: 0
# Chromosome Index: 97, PAR Value: 19647.4, GPU: 0
# Chromosome Index: 98, PAR Value: 19289.2, GPU: 1
# Chromosome Index: 99, PAR Value: 19639.7, GPU: 1
# Generation = 7
# Fitness    = 21222.9
# Change     = 318.6000000000022
# Chromosome Index: 6, PAR Value: 19502.8, GPU: 3
# Chromosome Index: 8, PAR Value: 19608.8, GPU: 0
# Chromosome Index: 1, PAR Value: 20510.0, GPU: 0
# Chromosome Index: 7, PAR Value: 19600.1, GPU: 3
# Chromosome Index: 3, PAR Value: 20248.5, GPU: 1
# Chromosome Index: 2, PAR Value: 20416.9, GPU: 1
# Chromosome Index: 5, PAR Value: 20728.8, GPU: 2
# Chromosome Index: 4, PAR Value: 20202.4, GPU: 2
# Chromosome Index: 9, PAR Value: 19364.4, GPU: 0
# Chromosome Index: 14, PAR Value: 19954.0, GPU: 3
# Chromosome Index: 10, PAR Value: 20480.7, GPU: 1
# Chromosome Index: 15, PAR Value: 21323.4, GPU: 3
# Chromosome Index: 11, PAR Value: 19984.6, GPU: 1
# Chromosome Index: 16, PAR Value: 20842.6, GPU: 0
# Chromosome Index: 12, PAR Value: 20220.4, GPU: 2
# Chromosome Index: 13, PAR Value: 19818.6, GPU: 2
# Chromosome Index: 17, PAR Value: 20824.9, GPU: 0
# Chromosome Index: 19, PAR Value: 20077.6, GPU: 1
# Chromosome Index: 18, PAR Value: 19994.5, GPU: 1
# Chromosome Index: 22, PAR Value: 21194.1, GPU: 3
# Chromosome Index: 23, PAR Value: 20437.4, GPU: 3
# Chromosome Index: 20, PAR Value: 20227.7, GPU: 2
# Chromosome Index: 24, PAR Value: 19998.9, GPU: 0
# Chromosome Index: 21, PAR Value: 19393.4, GPU: 2
# Chromosome Index: 25, PAR Value: 19922.6, GPU: 0
# Chromosome Index: 26, PAR Value: 19907.5, GPU: 1
# Chromosome Index: 27, PAR Value: 20456.7, GPU: 1
# Chromosome Index: 30, PAR Value: 21166.0, GPU: 3
# Chromosome Index: 29, PAR Value: 20768.0, GPU: 2
# Chromosome Index: 28, PAR Value: 20061.6, GPU: 2
# Chromosome Index: 31, PAR Value: 21687.1, GPU: 3
# Chromosome Index: 32, PAR Value: 19699.7, GPU: 0
# Chromosome Index: 33, PAR Value: 21137.0, GPU: 0
# Chromosome Index: 34, PAR Value: 21006.7, GPU: 1
# Chromosome Index: 35, PAR Value: 20881.9, GPU: 1
# Chromosome Index: 36, PAR Value: 20064.3, GPU: 2
# Chromosome Index: 37, PAR Value: 20610.6, GPU: 2
# Chromosome Index: 38, PAR Value: 20179.6, GPU: 3
# Chromosome Index: 39, PAR Value: 19383.1, GPU: 3
# Chromosome Index: 40, PAR Value: 20036.9, GPU: 0
# Chromosome Index: 41, PAR Value: 20013.5, GPU: 0
# Chromosome Index: 43, PAR Value: 20219.8, GPU: 1
# Chromosome Index: 42, PAR Value: 19311.7, GPU: 1
# Chromosome Index: 44, PAR Value: 20385.9, GPU: 2
# Chromosome Index: 46, PAR Value: 20326.6, GPU: 3
# Chromosome Index: 47, PAR Value: 20405.0, GPU: 3
# Chromosome Index: 45, PAR Value: 20899.9, GPU: 2
# Chromosome Index: 48, PAR Value: 20595.3, GPU: 0
# Chromosome Index: 49, PAR Value: 20497.3, GPU: 0
# Chromosome Index: 50, PAR Value: 20500.2, GPU: 1
# Chromosome Index: 51, PAR Value: 19605.3, GPU: 1
# Chromosome Index: 54, PAR Value: 19789.8, GPU: 3
# Chromosome Index: 52, PAR Value: 19374.6, GPU: 2
# Chromosome Index: 55, PAR Value: 21193.3, GPU: 3
# Chromosome Index: 53, PAR Value: 20391.8, GPU: 2
# Chromosome Index: 56, PAR Value: 19497.1, GPU: 0
# Chromosome Index: 57, PAR Value: 20398.1, GPU: 0
# Chromosome Index: 58, PAR Value: 19378.0, GPU: 1
# Chromosome Index: 59, PAR Value: 20824.7, GPU: 1
# Chromosome Index: 60, PAR Value: 19759.6, GPU: 2
# Chromosome Index: 62, PAR Value: 19027.5, GPU: 3
# Chromosome Index: 63, PAR Value: 19480.7, GPU: 3
# Chromosome Index: 64, PAR Value: 19730.5, GPU: 0
# Chromosome Index: 61, PAR Value: 19802.1, GPU: 2
# Chromosome Index: 65, PAR Value: 20058.6, GPU: 0
# Chromosome Index: 66, PAR Value: 20159.9, GPU: 1
# Chromosome Index: 67, PAR Value: 20456.8, GPU: 1
# Chromosome Index: 72, PAR Value: 19290.5, GPU: 0
# Chromosome Index: 68, PAR Value: 20711.9, GPU: 2
# Chromosome Index: 69, PAR Value: 20313.4, GPU: 2
# Chromosome Index: 73, PAR Value: 20938.5, GPU: 0
# Chromosome Index: 70, PAR Value: 20291.9, GPU: 3
# Chromosome Index: 71, PAR Value: 20300.4, GPU: 3
# Chromosome Index: 74, PAR Value: 21382.3, GPU: 1
# Chromosome Index: 75, PAR Value: 20186.0, GPU: 1
# Chromosome Index: 76, PAR Value: 19605.4, GPU: 2
# Chromosome Index: 77, PAR Value: 19733.4, GPU: 2
# Chromosome Index: 79, PAR Value: 19941.1, GPU: 3
# Chromosome Index: 78, PAR Value: 19419.6, GPU: 3
# Chromosome Index: 80, PAR Value: 19736.0, GPU: 0
# Chromosome Index: 81, PAR Value: 19574.1, GPU: 0
# Chromosome Index: 82, PAR Value: 20763.2, GPU: 1
# Chromosome Index: 83, PAR Value: 20882.8, GPU: 1
# Chromosome Index: 84, PAR Value: 20051.7, GPU: 2
# Chromosome Index: 85, PAR Value: 19686.3, GPU: 2
# Chromosome Index: 88, PAR Value: 20090.5, GPU: 0
# Chromosome Index: 87, PAR Value: 20036.2, GPU: 3
# Chromosome Index: 86, PAR Value: 19355.0, GPU: 3
# Chromosome Index: 89, PAR Value: 19054.4, GPU: 0
# Chromosome Index: 90, PAR Value: 20277.9, GPU: 1
# Chromosome Index: 91, PAR Value: 19327.3, GPU: 1
# Chromosome Index: 92, PAR Value: 19933.7, GPU: 2
# Chromosome Index: 93, PAR Value: 20773.2, GPU: 2
# Chromosome Index: 94, PAR Value: 20536.7, GPU: 3
# Chromosome Index: 95, PAR Value: 20070.7, GPU: 3
# Chromosome Index: 96, PAR Value: 20970.6, GPU: 0
# Chromosome Index: 97, PAR Value: 20068.1, GPU: 0
# Chromosome Index: 98, PAR Value: 20891.9, GPU: 1
# Chromosome Index: 99, PAR Value: 21569.2, GPU: 1
# Generation = 8
# Fitness    = 21687.1
# Change     = 464.1999999999971
# Chromosome Index: 5, PAR Value: 20517.3, GPU: 2
# Chromosome Index: 4, PAR Value: 20583.6, GPU: 2
# Chromosome Index: 2, PAR Value: 19782.3, GPU: 1
# Chromosome Index: 3, PAR Value: 21814.7, GPU: 1
# Chromosome Index: 8, PAR Value: 20328.7, GPU: 0
# Chromosome Index: 1, PAR Value: 19774.7, GPU: 0
# Chromosome Index: 6, PAR Value: 21552.2, GPU: 3
# Chromosome Index: 7, PAR Value: 20367.9, GPU: 3
# Chromosome Index: 9, PAR Value: 21214.7, GPU: 0
# Chromosome Index: 10, PAR Value: 20441.9, GPU: 1
# Chromosome Index: 11, PAR Value: 19792.3, GPU: 1
# Chromosome Index: 12, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 12, returning 0.0
# Chromosome Index: 14, PAR Value: 20742.2, GPU: 3
# Chromosome Index: 13, PAR Value: 19676.8, GPU: 2
# Chromosome Index: 15, PAR Value: 20540.4, GPU: 3
# Chromosome Index: 16, PAR Value: 20968.8, GPU: 0
# Chromosome Index: 20, PAR Value: 21103.5, GPU: 2
# Chromosome Index: 17, PAR Value: 21522.6, GPU: 0
# Chromosome Index: 21, PAR Value: 21179.3, GPU: 2
# Chromosome Index: 19, PAR Value: 20982.5, GPU: 1
# Chromosome Index: 18, PAR Value: 20295.8, GPU: 1
# Chromosome Index: 23, PAR Value: 21075.2, GPU: 3
# Chromosome Index: 22, PAR Value: 20382.4, GPU: 3
# Chromosome Index: 24, PAR Value: 21110.4, GPU: 0
# Chromosome Index: 25, PAR Value: 21119.2, GPU: 0
# Chromosome Index: 27, PAR Value: 21415.5, GPU: 1
# Chromosome Index: 26, PAR Value: 19736.5, GPU: 1
# Chromosome Index: 28, PAR Value: 21011.4, GPU: 2
# Chromosome Index: 29, PAR Value: 20761.3, GPU: 2
# Chromosome Index: 32, PAR Value: 20431.2, GPU: 0
# Chromosome Index: 30, PAR Value: 20135.3, GPU: 3
# Chromosome Index: 31, PAR Value: 20752.6, GPU: 3
# ...
# Chromosome Index: 28, PAR Value: 24389.4, GPU: 2
# Chromosome Index: 29, PAR Value: 24409.7, GPU: 2
# Chromosome Index: 32, PAR Value: 24369.5, GPU: 0
# Chromosome Index: 30, PAR Value: 24395.1, GPU: 3
# Chromosome Index: 31, PAR Value: 24312.3, GPU: 3
# Chromosome Index: 33, PAR Value: 24243.5, GPU: 0
# Chromosome Index: 34, PAR Value: 24160.6, GPU: 1
# Chromosome Index: 35, PAR Value: 24144.3, GPU: 1
# Chromosome Index: 36, PAR Value: 24244.0, GPU: 2
# Chromosome Index: 37, PAR Value: 24213.3, GPU: 2
# Chromosome Index: 40, PAR Value: 24291.8, GPU: 0
# Chromosome Index: 39, PAR Value: 24277.2, GPU: 3
# Chromosome Index: 38, PAR Value: 24387.4, GPU: 3
# Chromosome Index: 41, PAR Value: 24294.2, GPU: 0
# Chromosome Index: 42, PAR Value: 24282.4, GPU: 1
# Chromosome Index: 43, PAR Value: 24492.5, GPU: 1
# Chromosome Index: 44, PAR Value: 24494.7, GPU: 2
# Chromosome Index: 45, PAR Value: 24328.5, GPU: 2
# Chromosome Index: 46, PAR Value: 24315.8, GPU: 3
# Chromosome Index: 48, PAR Value: 24443.9, GPU: 0
# Chromosome Index: 47, PAR Value: 24355.5, GPU: 3
# Chromosome Index: 49, PAR Value: 24263.5, GPU: 0
# Chromosome Index: 50, PAR Value: 24196.9, GPU: 1
# Chromosome Index: 51, PAR Value: 24222.4, GPU: 1
# Chromosome Index: 52, PAR Value: 24385.1, GPU: 2
# Chromosome Index: 53, PAR Value: 24417.2, GPU: 2
# Chromosome Index: 54, PAR Value: 24417.8, GPU: 3
# Chromosome Index: 56, PAR Value: 24190.4, GPU: 0
# Chromosome Index: 55, PAR Value: 24180.9, GPU: 3
# Chromosome Index: 57, PAR Value: 24287.2, GPU: 0
# Chromosome Index: 58, PAR Value: 24400.6, GPU: 1
# Chromosome Index: 59, PAR Value: 24490.0, GPU: 1
# Chromosome Index: 60, PAR Value: 24087.4, GPU: 2
# Chromosome Index: 61, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 61, returning 0.0
# Chromosome Index: 64, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 64, returning 0.0
# Chromosome Index: 62, PAR Value: 24176.0, GPU: 3
# Chromosome Index: 65, PAR Value: 24243.1, GPU: 0
# Chromosome Index: 63, PAR Value: 24555.2, GPU: 3
# Chromosome Index: 66, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 66, returning 0.0
# Chromosome Index: 67, PAR Value: 24532.8, GPU: 1
# Chromosome Index: 68, PAR Value: 24192.1, GPU: 2
# Chromosome Index: 72, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 72, returning 0.0
# Chromosome Index: 69, PAR Value: 24293.2, GPU: 2
# Chromosome Index: 73, PAR Value: 24268.6, GPU: 0
# Chromosome Index: 71, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 71, returning 0.0
# Chromosome Index: 70, PAR Value: 24377.8, GPU: 3
# Chromosome Index: 74, PAR Value: 24252.3, GPU: 1
# Chromosome Index: 75, PAR Value: 24073.0, GPU: 1
# Chromosome Index: 76, PAR Value: 24255.8, GPU: 2
# Chromosome Index: 77, PAR Value: 24332.2, GPU: 2
# Chromosome Index: 78, PAR Value: 24268.9, GPU: 3
# Chromosome Index: 79, PAR Value: 24264.7, GPU: 3
# Chromosome Index: 81, PAR Value: 24461.8, GPU: 0
# Chromosome Index: 80, PAR Value: 24378.1, GPU: 0
# Chromosome Index: 82, PAR Value: 24437.9, GPU: 1
# Chromosome Index: 83, PAR Value: 24265.7, GPU: 1
# Chromosome Index: 84, PAR Value: 24451.1, GPU: 2
# Chromosome Index: 85, PAR Value: 24247.5, GPU: 2
# Chromosome Index: 86, PAR Value: 24347.2, GPU: 3
# Chromosome Index: 88, PAR Value: 24487.7, GPU: 0
# Chromosome Index: 87, PAR Value: 24383.5, GPU: 3
# Chromosome Index: 89, PAR Value: 24188.6, GPU: 0
# Chromosome Index: 90, PAR Value: 24292.0, GPU: 1
# Chromosome Index: 91, PAR Value: 24233.4, GPU: 1
# Chromosome Index: 92, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 92, returning 0.0
# Chromosome Index: 93, PAR Value: 24402.2, GPU: 2
# Chromosome Index: 96, PAR Value: 24355.3, GPU: 0
# Chromosome Index: 97, PAR Value: 24348.5, GPU: 0
# Chromosome Index: 95, PAR Value: 24271.7, GPU: 3
# Chromosome Index: 94, PAR Value: 24403.4, GPU: 3
# Chromosome Index: 99, PAR Value: 24208.7, GPU: 1
# Chromosome Index: 98, PAR Value: 24400.8, GPU: 1
# Generation = 98
# Fitness    = 24593.7
# Change     = 0.0
# Chromosome Index: 1, PAR Value: 24474.5, GPU: 0
# Chromosome Index: 2, PAR Value: 24332.5, GPU: 1
# Chromosome Index: 3, PAR Value: 24344.0, GPU: 1
# Chromosome Index: 8, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 8, returning 0.0
# Chromosome Index: 6, PAR Value: 24357.2, GPU: 3
# Chromosome Index: 7, PAR Value: 24435.2, GPU: 3
# Chromosome Index: 5, PAR Value: 24212.0, GPU: 2
# Chromosome Index: 4, PAR Value: 24279.3, GPU: 2
# Chromosome Index: 9, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 9, returning 0.0
# Chromosome Index: 10, PAR Value: 24204.7, GPU: 1
# Chromosome Index: 11, PAR Value: 24450.8, GPU: 1
# Chromosome Index: 14, PAR Value: 24433.4, GPU: 3
# Chromosome Index: 16, PAR Value: 24309.9, GPU: 0
# Chromosome Index: 12, PAR Value: 24597.4, GPU: 2
# Chromosome Index: 15, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 15, returning 0.0
# Chromosome Index: 13, PAR Value: 24360.9, GPU: 2
# Chromosome Index: 17, PAR Value: 24395.4, GPU: 0
# Chromosome Index: 18, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 18, returning 0.0
# Chromosome Index: 19, PAR Value: 24370.4, GPU: 1
# Chromosome Index: 24, PAR Value: 24467.9, GPU: 0
# Chromosome Index: 20, PAR Value: 24274.3, GPU: 2
# Chromosome Index: 21, PAR Value: 24103.9, GPU: 2
# Chromosome Index: 22, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 22, returning 0.0
# Chromosome Index: 23, PAR Value: 24319.4, GPU: 3
# Chromosome Index: 25, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 25, returning 0.0
# Chromosome Index: 26, PAR Value: 24181.7, GPU: 1
# Chromosome Index: 27, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 27, returning 0.0
# Chromosome Index: 28, PAR Value: 24285.6, GPU: 2
# Chromosome Index: 29, PAR Value: 24023.6, GPU: 2
# Chromosome Index: 32, PAR Value: 24292.1, GPU: 0
# Chromosome Index: 30, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 30, returning 0.0
# Chromosome Index: 31, PAR Value: 24065.5, GPU: 3
# Chromosome Index: 33, PAR Value: 24481.2, GPU: 0
# Chromosome Index: 34, PAR Value: 24315.8, GPU: 1
# Chromosome Index: 35, PAR Value: 24407.3, GPU: 1
# Chromosome Index: 36, PAR Value: 24318.9, GPU: 2
# Chromosome Index: 37, PAR Value: 24275.4, GPU: 2
# Chromosome Index: 38, PAR Value: 24537.2, GPU: 3
# Chromosome Index: 39, PAR Value: 24337.2, GPU: 3
# Chromosome Index: 40, PAR Value: 24299.9, GPU: 0
# Chromosome Index: 41, PAR Value: 24454.8, GPU: 0
# Chromosome Index: 42, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 42, returning 0.0
# Chromosome Index: 43, PAR Value: 24502.5, GPU: 1
# Chromosome Index: 44, PAR Value: 24211.2, GPU: 2
# Chromosome Index: 45, PAR Value: 24431.0, GPU: 2
# Chromosome Index: 46, PAR Value: 24243.7, GPU: 3
# Chromosome Index: 48, PAR Value: 24442.5, GPU: 0
# Chromosome Index: 47, PAR Value: 24388.0, GPU: 3
# Chromosome Index: 49, PAR Value: 24555.4, GPU: 0
# Chromosome Index: 50, PAR Value: 24475.4, GPU: 1
# Chromosome Index: 51, PAR Value: 24384.4, GPU: 1
# Chromosome Index: 52, PAR Value: 24363.2, GPU: 2
# Chromosome Index: 53, PAR Value: 24140.3, GPU: 2
# Chromosome Index: 56, PAR Value: 24420.5, GPU: 0
# Chromosome Index: 55, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 55, returning 0.0
# Chromosome Index: 54, PAR Value: 24190.5, GPU: 3
# Chromosome Index: 57, PAR Value: 24418.2, GPU: 0
# Chromosome Index: 59, PAR Value: 24149.0, GPU: 1
# Chromosome Index: 58, PAR Value: 24190.2, GPU: 1
# Chromosome Index: 60, PAR Value: 24360.2, GPU: 2
# Chromosome Index: 61, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 61, returning 0.0
# Chromosome Index: 64, PAR Value: 24263.3, GPU: 0
# Chromosome Index: 62, PAR Value: 24275.7, GPU: 3
# Chromosome Index: 65, PAR Value: 24367.4, GPU: 0
# Chromosome Index: 63, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 63, returning 0.0
# Chromosome Index: 66, PAR Value: 24286.4, GPU: 1
# Chromosome Index: 67, PAR Value: 24228.2, GPU: 1
# Chromosome Index: 68, PAR Value: 24450.3, GPU: 2
# Chromosome Index: 69, PAR Value: 24145.9, GPU: 2
# Chromosome Index: 70, PAR Value: 24240.8, GPU: 3
# Chromosome Index: 72, PAR Value: 24122.8, GPU: 0
# Chromosome Index: 71, PAR Value: 24559.7, GPU: 3
# Chromosome Index: 73, PAR Value: 24405.4, GPU: 0
# Chromosome Index: 74, PAR Value: 24151.5, GPU: 1
# Chromosome Index: 75, PAR Value: 24165.7, GPU: 1
# Chromosome Index: 76, PAR Value: 24352.7, GPU: 2
# Chromosome Index: 77, PAR Value: 24186.0, GPU: 2
# Chromosome Index: 78, PAR Value: 24446.0, GPU: 3
# Chromosome Index: 80, PAR Value: 24418.8, GPU: 0
# Chromosome Index: 79, PAR Value: 24406.8, GPU: 3
# Chromosome Index: 81, PAR Value: 24330.9, GPU: 0
# Chromosome Index: 82, PAR Value: 24344.7, GPU: 1
# Chromosome Index: 83, PAR Value: 24210.2, GPU: 1
# Chromosome Index: 84, PAR Value: 24515.4, GPU: 2
# Chromosome Index: 85, PAR Value: 24272.4, GPU: 2
# Chromosome Index: 86, PAR Value: 24080.0, GPU: 3
# Chromosome Index: 87, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 87, returning 0.0
# Chromosome Index: 88, PAR Value: 24110.0, GPU: 0
# Chromosome Index: 89, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 89, returning 0.0
# Chromosome Index: 90, PAR Value: 24416.1, GPU: 1
# Chromosome Index: 91, PAR Value: 24388.6, GPU: 1
# Chromosome Index: 92, PAR Value: 24427.4, GPU: 2
# Chromosome Index: 93, PAR Value: 24196.1, GPU: 2
# Chromosome Index: 96, PAR Value: 24201.2, GPU: 0
# Chromosome Index: 94, PAR Value: 24333.7, GPU: 3
# Chromosome Index: 95, PAR Value: 24405.9, GPU: 3
# Chromosome Index: 97, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 97, returning 0.0
# Chromosome Index: 98, PAR Value: 24256.2, GPU: 1
# Chromosome Index: 99, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 99, returning 0.0
# Generation = 99
# Fitness    = 24597.4
# Change     = 3.7000000000007276
# Chromosome Index: 1, PAR Value: 24441.4, GPU: 0
# Chromosome Index: 2, PAR Value: 24315.3, GPU: 1
# Chromosome Index: 3, PAR Value: 24361.3, GPU: 1
# Chromosome Index: 8, PAR Value: 24384.9, GPU: 0
# Chromosome Index: 6, PAR Value: 24638.8, GPU: 3
# Chromosome Index: 7, PAR Value: 24332.9, GPU: 3
# Chromosome Index: 4, PAR Value: 24503.3, GPU: 2
# Chromosome Index: 5, PAR Value: 24288.1, GPU: 2
# Chromosome Index: 9, PAR Value: 24480.2, GPU: 0
# Chromosome Index: 10, PAR Value: 24222.5, GPU: 1
# Chromosome Index: 11, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 11, returning 0.0
# Chromosome Index: 14, PAR Value: 24188.5, GPU: 3
# Chromosome Index: 12, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 12, returning 0.0
# Chromosome Index: 15, PAR Value: 24250.1, GPU: 3
# Chromosome Index: 13, PAR Value: 24305.1, GPU: 2
# Chromosome Index: 16, PAR Value: 24326.9, GPU: 0
# Chromosome Index: 17, PAR Value: 24507.7, GPU: 0
# Chromosome Index: 18, PAR Value: 24477.6, GPU: 1
# Chromosome Index: 19, PAR Value: 24069.1, GPU: 1
# Chromosome Index: 22, PAR Value: 24198.2, GPU: 3
# Chromosome Index: 23, PAR Value: 24387.6, GPU: 3
# Chromosome Index: 20, PAR Value: 24208.1, GPU: 2
# Chromosome Index: 21, PAR Value: 24192.1, GPU: 2
# Chromosome Index: 24, PAR Value: 24111.9, GPU: 0
# Chromosome Index: 25, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 25, returning 0.0
# Chromosome Index: 26, PAR Value: 24170.4, GPU: 1
# Chromosome Index: 27, PAR Value: 24478.9, GPU: 1
# Chromosome Index: 30, PAR Value: 24349.1, GPU: 3
# Chromosome Index: 28, PAR Value: 24280.9, GPU: 2
# Chromosome Index: 31, PAR Value: 24454.8, GPU: 3
# Chromosome Index: 29, PAR Value: 24129.1, GPU: 2
# Chromosome Index: 32, PAR Value: 24442.2, GPU: 0
# Chromosome Index: 33, PAR Value: 24554.6, GPU: 0
# Chromosome Index: 34, PAR Value: 24459.7, GPU: 1
# Chromosome Index: 35, PAR Value: 24322.9, GPU: 1
# Chromosome Index: 40, PAR Value: 24312.9, GPU: 0
# Chromosome Index: 36, PAR Value: 24403.6, GPU: 2
# Chromosome Index: 37, PAR Value: 24220.6, GPU: 2
# Chromosome Index: 38, PAR Value: 24315.5, GPU: 3
# Chromosome Index: 39, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 39, returning 0.0
# Chromosome Index: 41, PAR Value: 24380.9, GPU: 0
# Chromosome Index: 42, PAR Value: 24328.1, GPU: 1
# Chromosome Index: 43, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 43, returning 0.0
# Chromosome Index: 44, PAR Value: 24265.5, GPU: 2
# Chromosome Index: 45, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 45, returning 0.0
# Chromosome Index: 46, PAR Value: 24388.8, GPU: 3
# Chromosome Index: 47, PAR Value: 24210.0, GPU: 3
# Chromosome Index: 48, PAR Value: 24485.2, GPU: 0
# Chromosome Index: 49, PAR Value: 24576.1, GPU: 0
# Chromosome Index: 50, PAR Value: 24189.2, GPU: 1
# Chromosome Index: 51, PAR Value: 24113.8, GPU: 1
# Chromosome Index: 52, PAR Value: 24392.6, GPU: 2
# Chromosome Index: 53, PAR Value: 24329.2, GPU: 2
# Chromosome Index: 54, PAR Value: 24002.0, GPU: 3
# Chromosome Index: 55, PAR Value: 24319.0, GPU: 3
# Chromosome Index: 56, PAR Value: 24355.7, GPU: 0
# Chromosome Index: 57, PAR Value: 24344.5, GPU: 0
# Chromosome Index: 58, PAR Value: 24306.7, GPU: 1
# Chromosome Index: 59, PAR Value: 24283.3, GPU: 1
# Chromosome Index: 60, PAR Value: 24585.6, GPU: 2
# Chromosome Index: 61, PAR Value: 24333.0, GPU: 2
# Chromosome Index: 64, PAR Value: 24388.1, GPU: 0
# Chromosome Index: 62, PAR Value: 24109.6, GPU: 3
# Chromosome Index: 63, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 63, returning 0.0
# Chromosome Index: 65, PAR Value: 24333.5, GPU: 0
# Chromosome Index: 66, PAR Value: 24556.6, GPU: 1
# Chromosome Index: 67, PAR Value: 24377.6, GPU: 1
# Chromosome Index: 68, PAR Value: 24074.2, GPU: 2
# Chromosome Index: 69, PAR Value: 24389.2, GPU: 2
# Chromosome Index: 70, PAR Value: 24259.6, GPU: 3
# Chromosome Index: 71, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 71, returning 0.0
# Chromosome Index: 73, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 73, returning 0.0
# Chromosome Index: 72, PAR Value: 24277.9, GPU: 0
# Chromosome Index: 74, PAR Value: 24450.7, GPU: 1
# Chromosome Index: 75, PAR Value: 24334.6, GPU: 1
# Chromosome Index: 76, PAR Value: nan, GPU: 2
# PAR is NaN for chromosome index 76, returning 0.0
# Chromosome Index: 77, PAR Value: 24402.6, GPU: 2
# Chromosome Index: 78, PAR Value: 24263.8, GPU: 3
# Chromosome Index: 81, PAR Value: 24189.2, GPU: 0
# Chromosome Index: 79, PAR Value: 24345.5, GPU: 3
# Chromosome Index: 80, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 80, returning 0.0
# Chromosome Index: 82, PAR Value: 24346.8, GPU: 1
# Chromosome Index: 83, PAR Value: 24217.2, GPU: 1
# Chromosome Index: 84, PAR Value: 24363.9, GPU: 2
# Chromosome Index: 85, PAR Value: 24429.9, GPU: 2
# Chromosome Index: 86, PAR Value: nan, GPU: 3
# PAR is NaN for chromosome index 86, returning 0.0
# Chromosome Index: 87, PAR Value: 24248.0, GPU: 3
# Chromosome Index: 89, PAR Value: 24330.8, GPU: 0
# Chromosome Index: 88, PAR Value: 24203.2, GPU: 0
# Chromosome Index: 90, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 90, returning 0.0
# Chromosome Index: 91, PAR Value: 24254.2, GPU: 1
# Chromosome Index: 92, PAR Value: 24248.4, GPU: 2
# Chromosome Index: 93, PAR Value: 24447.7, GPU: 2
# Chromosome Index: 94, PAR Value: 24489.2, GPU: 3
# Chromosome Index: 95, PAR Value: 24203.2, GPU: 3
# Chromosome Index: 97, PAR Value: nan, GPU: 0
# PAR is NaN for chromosome index 97, returning 0.0
# Chromosome Index: 96, PAR Value: 24204.1, GPU: 0
# Chromosome Index: 98, PAR Value: nan, GPU: 1
# PAR is NaN for chromosome index 98, returning 0.0
# Chromosome Index: 99, PAR Value: 24337.7, GPU: 1
# Generation = 100
# Fitness    = 24638.8
# Change     = 41.39999999999782
# Time is 288174.08203339577
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Best Solution: [109.03913467  87.80138402 107.63606007  90.4268799  108.89036573
#  107.82341272 108.38524461  94.54970513 107.32545006  46.54773915
#   93.17659541  48.30202552  13.95204877  13.88411098  13.89086776
#   13.69826168  12.72048003  13.1725313   13.47435153   9.87534939
#   13.70146064  13.49464519  13.95354975  13.90338673 259.34779624
#  103.78439992 250.50816174 257.74833986 240.10283702 267.67567611
#  291.57593356  68.45468814  71.22914571 123.8374086  119.60615942
#  353.40513412 -29.30606314  37.30341071 -23.23507591   1.50716996
#  -40.63743467 -29.31870332 -18.48458123 -30.02051011 -12.09448343
#  -18.69344219  -1.13307973   2.29461819]
# Fitness value of the best solution = 24638.8
